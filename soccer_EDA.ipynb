# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
prem_team_stats = pd.read_csv('../../footy_data/england-premier-league-teams-2021-to-2022-stats.csv')
prem_games = pd.read_csv('../../footy_data/england-premier-league-matches-2021-to-2022-stats.csv')
champ_team_stats = pd.read_csv('../../footy_data/england-championship-teams-2021-to-2022-stats.csv')
champ_games = pd.read_csv('../../footy_data/england-championship-matches-2021-to-2022-stats.csv')
league_one_team_stats = pd.read_csv('../../footy_data/england-efl-league-one-teams-2021-to-2022-stats.csv')
league_one_games = pd.read_csv('../../footy_data/england-efl-league-one-matches-2021-to-2022-stats.csv')
league_two_team_stats = pd.read_csv('../../footy_data/england-efl-league-two-teams-2021-to-2022-stats.csv')
league_two_games = pd.read_csv('../../footy_data/england-efl-league-two-matches-2021-to-2022-stats.csv')
segunda_team_stats = pd.read_csv('../../footy_data/spain-segunda-division-teams-2021-to-2022-stats.csv')
segunda_games = pd.read_csv('../../footy_data/spain-segunda-division-matches-2021-to-2022-stats.csv')
laliga_team_stats = pd.read_csv('../../footy_data/spain-la-liga-teams-2021-to-2022-stats.csv')
laliga_games = pd.read_csv('../../footy_data/spain-la-liga-matches-2021-to-2022-stats.csv')

# %%
prem_games = prem_games.loc[prem_games['status'] == 'complete']
champ_games = champ_games.loc[champ_games['status'] == 'complete']
league_one_games = league_one_games.loc[league_one_games['status'] == 'complete']
league_two_games = league_two_games.loc[league_two_games['status'] == 'complete']
segunda_games = segunda_games.loc[segunda_games['status'] == 'complete']
laliga_games = laliga_games.loc[laliga_games['status'] == 'complete']
#Played matches

# %%
champ_team_stats['real_xg'] = ""
champ_team_stats['real_xga'] = ""
league_one_team_stats['real_xg'] = ""
league_one_team_stats['real_xga'] = ""
league_two_team_stats['real_xg'] = ""
league_two_team_stats['real_xga'] = ""
segunda_team_stats['real_xg'] = ""
segunda_team_stats['real_xga'] = ""
prem_team_stats['real_xg'] = ""
prem_team_stats['real_xga'] = ""
laliga_team_stats['real_xg'] = ""
laliga_team_stats['real_xga'] = ""
#Setting up to fix xg and xga

# %% [markdown]
# The average xG stats for each team in Footystats' spreadsheet is incorrect, so I'll write a function to fill it myself

# %%
def xg_fixer(team_name, team_stats, league_games):
    total = league_games.loc[league_games['home_team_name'] == team_name, 'team_a_xg'].sum()
    total = total + league_games.loc[league_games['away_team_name'] == team_name, 'team_b_xg'].sum()
    total = total / (team_stats.loc[team_stats['common_name'] == team_name, 'matches_played'].iloc[0])
    team_stats['real_xg'] = np.where(team_stats['common_name'] == team_name, total, team_stats['real_xg'])

# %%
def xg_against_fixer(team_name, team_stats, league_games):
    total = league_games.loc[league_games['home_team_name'] == team_name, 'team_b_xg'].sum()
    #Want team B this time because we want goals against
    total = total + league_games.loc[league_games['away_team_name'] == team_name, 'team_a_xg'].sum()
    total = total / (team_stats.loc[team_stats['common_name'] == team_name, 'matches_played'].iloc[0])
    team_stats['real_xga'] = np.where(team_stats['common_name'] == team_name, total, team_stats['real_xga'])

# %% [markdown]
# # Fix xG and xGA

# %% [markdown]
# Leagues with 24 teams

# %%
for i in range (0,24):
    xg_fixer(champ_team_stats['common_name'][i], champ_team_stats, champ_games)
    xg_fixer(league_one_team_stats['common_name'][i], league_one_team_stats, league_one_games)
    xg_fixer(league_two_team_stats['common_name'][i], league_two_team_stats, league_two_games)
    xg_against_fixer(champ_team_stats['common_name'][i], champ_team_stats, champ_games)
    xg_against_fixer(league_one_team_stats['common_name'][i], league_one_team_stats, league_one_games)
    xg_against_fixer(league_two_team_stats['common_name'][i], league_two_team_stats, league_two_games)

# %% [markdown]
# Leagues with 22 Teams

# %%
for i in range (0,22):
    xg_fixer(segunda_team_stats['common_name'][i], segunda_team_stats, segunda_games)
    xg_against_fixer(segunda_team_stats['common_name'][i], segunda_team_stats, segunda_games)

# %% [markdown]
# Leagues with 20 Teams

# %%
for i in range (0,20):
    xg_fixer(prem_team_stats['common_name'][i], prem_team_stats, prem_games)
    xg_fixer(laliga_team_stats['common_name'][i], laliga_team_stats, laliga_games)
    xg_against_fixer(prem_team_stats['common_name'][i], prem_team_stats, prem_games)
    xg_against_fixer(laliga_team_stats['common_name'][i], laliga_team_stats, laliga_games)

# %% [markdown]
# # Fill Stats

# %%
champ_games['home_xg'] = ""
champ_games['away_xg'] = ""
champ_games['home_xg_against'] = ""
champ_games['away_xg_against'] = ""
champ_games['home_total_corners'] = ""
champ_games['away_total_corners'] = ""

laliga_games['home_xg'] = ""
laliga_games['away_xg'] = ""
laliga_games['home_xg_against'] = ""
laliga_games['away_xg_against'] = ""
laliga_games['home_total_corners'] = ""
laliga_games['away_total_corners'] = ""

segunda_games['home_xg'] = ""
segunda_games['away_xg'] = ""
segunda_games['home_xg_against'] = ""
segunda_games['away_xg_against'] = ""
segunda_games['home_total_corners'] = ""
segunda_games['away_total_corners'] = ""

league_one_games['home_xg'] = ""
league_one_games['away_xg'] = ""
league_one_games['home_xg_against'] = ""
league_one_games['away_xg_against'] = ""
league_one_games['home_total_corners'] = ""
league_one_games['away_total_corners'] = ""

league_two_games['home_xg'] = ""
league_two_games['away_xg'] = ""
league_two_games['home_xg_against'] = ""
league_two_games['away_xg_against'] = ""
league_two_games['home_total_corners'] = ""
league_two_games['away_total_corners'] = ""

prem_games['home_xg'] = ""
prem_games['away_xg'] = ""
prem_games['home_xg_against'] = ""
prem_games['away_xg_against'] = ""
prem_games['home_total_corners'] = ""
prem_games['away_total_corners'] = ""

# Creating new columns where our xg and corner data will go

# %%
prem_xg_stats = dict(prem_team_stats[['common_name', 'real_xg']].values)
prem_corner_stats = dict(prem_team_stats[['common_name', 'corners_per_match']].values)
prem_xga_stats = dict(prem_team_stats[['common_name', 'real_xga']].values)
champ_xg_stats = dict(champ_team_stats[['common_name', 'real_xg']].values)
champ_corner_stats = dict(champ_team_stats[['common_name', 'corners_per_match']].values)
champ_xga_stats = dict(champ_team_stats[['common_name', 'real_xga']].values)
league_one_xg_stats = dict(league_one_team_stats[['common_name', 'real_xg']].values)
league_one_corner_stats = dict(league_one_team_stats[['common_name', 'corners_per_match']].values)
league_one_xga_stats = dict(league_one_team_stats[['common_name', 'real_xga']].values)
league_two_xg_stats = dict(league_two_team_stats[['common_name', 'real_xg']].values)
league_two_corner_stats = dict(league_two_team_stats[['common_name', 'corners_per_match']].values)
league_two_xga_stats = dict(league_two_team_stats[['common_name', 'real_xga']].values)
laliga_xg_stats = dict(laliga_team_stats[['common_name', 'real_xg']].values)
laliga_corner_stats = dict(laliga_team_stats[['common_name', 'real_xg']].values)
laliga_xga_stats = dict(laliga_team_stats[['common_name', 'real_xg']].values)
segunda_xg_stats = dict(segunda_team_stats[['common_name', 'real_xg']].values)
segunda_corner_stats = dict(segunda_team_stats[['common_name', 'corners_per_match']].values)
segunda_xga_stats = dict(segunda_team_stats[['common_name', 'real_xga']].values)
#creating new variables for the average stats -- eventually will go into the GAMES df for the leagues
#By making this into dictionaries, it will be easier to call them/update them with the function

# %%
def fill_stats(team, games, xg_stats, xga_stats, corner_stats):
    games['home_xg'] = np.where(games['home_team_name'] == team, xg_stats[team], games['home_xg'])
    games['away_xg'] = np.where(games['away_team_name'] == team, xg_stats[team], games['away_xg'])
    games['home_xg_against'] = np.where(games['home_team_name'] == team, xga_stats[team], games['home_xg_against'])
    games['away_xg_against'] = np.where(games['away_team_name'] == team, xga_stats[team], games['away_xg_against'])
    games['home_total_corners'] = np.where(games['home_team_name'] == team, corner_stats[team], games['home_total_corners'])
    games['away_total_corners'] = np.where(games['away_team_name'] == team, corner_stats[team], games['away_total_corners'])
#Function to put team stats into games dataframe

# %% [markdown]
# 24 Team Leagues

# %%
for i in range (0,24):
    fill_stats(champ_team_stats['common_name'][i], champ_games, champ_xg_stats, champ_xga_stats, champ_corner_stats)
    fill_stats(league_one_team_stats['common_name'][i], league_one_games, league_one_xg_stats, league_one_xga_stats, league_one_corner_stats)
    fill_stats(league_two_team_stats['common_name'][i], league_two_games, league_two_xg_stats, league_two_xga_stats, league_two_corner_stats)
#Filling stats in for leagues with 24 teams

# %% [markdown]
# 22 Team Leagues

# %%
for i in range (0,22):
    fill_stats(segunda_team_stats['common_name'][i], segunda_games, segunda_xg_stats, segunda_xga_stats, segunda_corner_stats)

# %% [markdown]
# 20 Team Leagues

# %%
for i in range (0,20):
    fill_stats(laliga_team_stats['common_name'][i], laliga_games, laliga_xg_stats, laliga_xga_stats, laliga_corner_stats)
    fill_stats(prem_team_stats['common_name'][i], prem_games, prem_xg_stats, prem_xga_stats, prem_corner_stats)

# %% [markdown]
# # English Championship

# %%
xg_view = champ_games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[(len(champ_games) - 50):len(champ_games)]
#We just want to see the most recent games here
# Out:
#            home_team_name        away_team_name  team_a_xg  team_b_xg  \
# 236            Stoke City      Blackburn Rovers       1.18       0.93
# 237          Swansea City               Reading       3.00       1.24
# 238      Sheffield United          Bristol City       2.30       0.96
# 239          Derby County   Queens Park Rangers       0.90       1.49
# 240                Fulham       AFC Bournemouth       2.69       0.98
# 241         Coventry City  West Bromwich Albion       1.46       1.72
# 242              Barnsley     Huddersfield Town       1.41       1.91
# 243      Blackburn Rovers     Preston North End       1.00       1.18
# 244             Blackpool            Luton Town       1.39       1.38
# 245          Bristol City          Derby County       0.90       1.15
# 246          Cardiff City      Sheffield United       1.22       1.99
# 247         Middlesbrough          Swansea City       0.91       1.68
# 248              Millwall       Birmingham City       2.37       1.73
# 249     Nottingham Forest   Peterborough United       1.60       1.21
# 250               Reading             Hull City       2.10       1.55
# 251   Queens Park Rangers            Stoke City       2.57       2.10
# 252     Huddersfield Town         Coventry City       1.16       2.83
# 253       AFC Bournemouth      Blackburn Rovers       1.81       1.51
# 254       Birmingham City          Cardiff City       1.32       2.11
# 255          Derby County             Blackpool       1.09       0.96
# 256             Hull City          Bristol City       1.57       1.21
# 257            Luton Town                Fulham       1.06       1.55
# 258   Peterborough United              Millwall       2.23       1.62
# 259     Preston North End              Barnsley       1.67       1.37
# 260            Stoke City         Middlesbrough       1.06       0.93
# 261          Swansea City     Nottingham Forest       1.32       1.04
# 262  West Bromwich Albion               Reading       2.84       0.56
# 264              Barnsley  West Bromwich Albion       0.54       1.65
# 266         Middlesbrough       AFC Bournemouth       2.17       1.21
# 267      Blackburn Rovers       Birmingham City       1.67       1.06
# 268             Blackpool   Peterborough United       1.97       1.03
# 269          Bristol City     Huddersfield Town       2.04       1.47
# 271     Nottingham Forest             Hull City       1.29       1.30
# 272                Fulham      Sheffield United       1.33       0.63
# 275     Huddersfield Town             Blackpool       1.97       1.14
# 277         Middlesbrough     Nottingham Forest       1.79       0.82
# 279          Derby County  West Bromwich Albion       0.55       2.21
# 280   Queens Park Rangers       AFC Bournemouth       1.30       1.88
# 283      Blackburn Rovers              Barnsley       1.19       0.79
# 284             Blackpool         Middlesbrough       1.25       1.08
# 285         Coventry City              Millwall       1.55       0.77
# 288       AFC Bournemouth          Cardiff City       2.17       0.91
# 289          Bristol City   Queens Park Rangers       1.34       1.40
# 290     Nottingham Forest     Huddersfield Town       2.41       1.05
# 291            Stoke City          Derby County       1.06       1.23
# 293             Blackpool             Hull City       1.12       1.70
# 295          Bristol City              Millwall       0.00       0.00
# 296       Birmingham City   Queens Park Rangers       0.00       0.00
# 297      Blackburn Rovers     Huddersfield Town       0.00       0.00
# 298  West Bromwich Albion          Cardiff City       0.00       0.00
#
#      home_team_goal_count  away_team_goal_count
# 236                     0                     1
# 237                     2                     3
# 238                     2                     0
# 239                     1                     2
# 240                     1                     1
# 241                     1                     2
# 242                     1                     1
# 243                     1                     0
# 244                     0                     3
# 245                     1                     0
# 246                     2                     3
# 247                     1                     0
# 248                     3                     1
# 249                     2                     0
# 250                     1                     1
# 251                     0                     2
# 252                     1                     1
# 253                     0                     2
# 254                     2                     2
# 255                     1                     0
# 256                     2                     2
# 257                     1                     1
# 258                     2                     1
# 259                     2                     1
# 260                     0                     0
# 261                     1                     4
# 262                     1                     0
# 264                     0                     0
# 266                     1                     0
# 267                     4                     0
# 268                     3                     1
# 269                     2                     3
# 271                     2                     1
# 272                     0                     1
# 275                     3                     2
# 277                     2                     0
# 279                     1                     0
# 280                     0                     1
# 283                     2                     1
# 284                     1                     2
# 285                     0                     1
# 288                     3                     0
# 289                     1                     2
# 290                     0                     1
# 291                     1                     2
# 293                     1                     0
# 295                     3                     2
# 296                     1                     2
# 297                     0                     0
# 298                     1                     1

# %% [markdown]
# # Goal Analysis

# %%
season_goal_total = champ_games['total_goal_count'].sum()
season_1h_goal_total = champ_games['total_goals_at_half_time'].sum()
percent_goals_1h = ((season_1h_goal_total)/(season_goal_total)) * 100

# %%
print(f'There were {season_goal_total} goals scored this season')
# Out:
# There were 699 goals scored this season

# %%
print(f'There were {season_1h_goal_total} goals scored in the 1H this season, ')
# Out:
# There were 286 goals scored in the 1H this season,

# %%
round(season_1h_goal_total/season_goal_total, 2)
#% of first half goals
# Out:
# 0.41

# %%
champ_games['total_goals_at_half_time'].value_counts()
# Out:
# 1    115
# 0     96
# 2     58
# 3     13
# 4      4
# Name: total_goals_at_half_time, dtype: int64

# %% [markdown]
# # Over/Under 2.5?

# %%
champ_games['over/under'] = np.where(champ_games['home_team_goal_count'] + champ_games['away_team_goal_count'] > 2.5, 1, 0)
# Adding column 0 represents under 2.5, 1 represents over 2.5

# %%
champ_games['over/under'].value_counts()
# Out:
# 0    153
# 1    133
# Name: over/under, dtype: int64

# %% [markdown]
# # League One

# %%
xg_view = league_one_games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[(len(league_one_games) - 50):len(league_one_games)]
# Out:
#          home_team_name       away_team_name  team_a_xg  team_b_xg  \
# 231        Ipswich Town      Crewe Alexandra       1.92       1.18
# 232  Accrington Stanley       Fleetwood Town       1.66       0.76
# 233          Sunderland        Oxford United       1.85       1.14
# 234  Accrington Stanley        AFC Wimbledon       1.69       1.20
# 235   Charlton Athletic         Ipswich Town       2.38       0.73
# 236     Cheltenham Town     Cambridge United       1.05       1.98
# 237     Crewe Alexandra         Lincoln City       1.94       1.28
# 238    Doncaster Rovers        Oxford United       1.20       1.86
# 239      Fleetwood Town     Bolton Wanderers       1.14       1.47
# 240          Portsmouth  Sheffield Wednesday       1.46       1.04
# 241    Rotherham United           Gillingham       2.62       0.48
# 242          Sunderland            Morecambe       2.11       1.05
# 243   Wycombe Wanderers        Burton Albion       2.08       1.24
# 244  Milton Keynes Dons      Plymouth Argyle       1.16       1.20
# 245      Wigan Athletic      Shrewsbury Town       1.69       1.17
# 246  Accrington Stanley     Bolton Wanderers       1.91       0.99
# 247   Charlton Athletic     Cambridge United       1.44       1.25
# 248     Cheltenham Town         Lincoln City       1.84       1.88
# 249     Crewe Alexandra  Sheffield Wednesday       0.94       1.62
# 250    Doncaster Rovers      Shrewsbury Town       1.15       1.52
# 251      Fleetwood Town           Gillingham       1.64       1.13
# 252  Milton Keynes Dons        Oxford United       1.31       1.78
# 253          Portsmouth            Morecambe       1.78       1.52
# 254    Rotherham United        Burton Albion       1.78       1.67
# 255          Sunderland      Plymouth Argyle       2.20       1.27
# 256      Wigan Athletic         Ipswich Town       0.75       1.22
# 257   Wycombe Wanderers        AFC Wimbledon       2.44       1.63
# 259    Cambridge United     Rotherham United       0.93       1.65
# 261        Ipswich Town           Sunderland       1.76       0.83
# 263           Morecambe       Fleetwood Town       1.05       1.14
# 264       Oxford United       Wigan Athletic       1.51       1.22
# 265     Plymouth Argyle    Charlton Athletic       1.53       1.23
# 267     Shrewsbury Town      Cheltenham Town       1.37       2.96
# 269  Accrington Stanley     Rotherham United       1.97       1.61
# 271     Cheltenham Town      Plymouth Argyle       1.09       1.26
# 273      Fleetwood Town      Shrewsbury Town       0.79       1.62
# 274        Lincoln City   Milton Keynes Dons       1.12       1.75
# 278    Doncaster Rovers           Sunderland       0.93       2.30
# 281        Ipswich Town    Wycombe Wanderers       0.98       1.12
# 283           Morecambe      Crewe Alexandra       1.10       0.96
# 284       Oxford United        AFC Wimbledon       1.68       0.59
# 287     Shrewsbury Town   Accrington Stanley       1.11       1.43
# 290          Sunderland  Sheffield Wednesday       2.01       1.38
# 291       Burton Albion      Crewe Alexandra       2.27       1.24
# 292   Charlton Athletic    Wycombe Wanderers       1.42       1.35
# 294  Milton Keynes Dons           Gillingham       1.74       0.80
# 295       Oxford United      Cheltenham Town       1.78       1.23
# 297    Rotherham United     Bolton Wanderers       2.00       1.43
# 300           Morecambe     Doncaster Rovers       0.00       0.00
# 301     Shrewsbury Town  Sheffield Wednesday       0.00       0.00
#
#      home_team_goal_count  away_team_goal_count
# 231                     2                     1
# 232                     5                     1
# 233                     1                     1
# 234                     0                     2
# 235                     2                     0
# 236                     0                     5
# 237                     2                     0
# 238                     1                     2
# 239                     3                     0
# 240                     0                     0
# 241                     5                     1
# 242                     5                     0
# 243                     2                     1
# 244                     1                     1
# 245                     2                     1
# 246                     1                     0
# 247                     2                     0
# 248                     2                     2
# 249                     0                     2
# 250                     1                     0
# 251                     2                     1
# 252                     1                     2
# 253                     2                     0
# 254                     3                     1
# 255                     2                     1
# 256                     1                     1
# 257                     2                     2
# 259                     0                     1
# 261                     1                     1
# 263                     0                     0
# 264                     2                     3
# 265                     1                     0
# 267                     3                     1
# 269                     1                     0
# 271                     0                     2
# 273                     0                     3
# 274                     2                     3
# 278                     0                     3
# 281                     1                     0
# 283                     1                     2
# 284                     3                     0
# 287                     0                     0
# 290                     5                     0
# 291                     4                     1
# 292                     0                     1
# 294                     0                     0
# 295                     1                     1
# 297                     2                     1
# 300                     4                     3
# 301                     1                     0

# %% [markdown]
# # League Two

# %%
xg_view = league_two_games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[(len(league_two_games) - 50):len(league_two_games)]
# Out:
#           home_team_name       away_team_name  team_a_xg  team_b_xg  \
# 215      Carlisle United              Walsall       1.18       1.61
# 216         Crawley Town       Mansfield Town       1.01       1.22
# 217  Forest Green Rovers       Bristol Rovers       1.45       1.35
# 218     Northampton Town        Leyton Orient       0.92       1.17
# 219            Port Vale    Hartlepool United       1.66       0.67
# 220             Rochdale          Exeter City       1.68       1.61
# 221         Salford City      Oldham Athletic       1.72       1.27
# 222    Scunthorpe United        Bradford City       1.46       2.10
# 223        Sutton United               Barrow       1.23       1.56
# 224         Swindon Town       Harrogate Town       1.56       1.74
# 225       Bristol Rovers            Port Vale       0.74       1.92
# 226          Exeter City     Northampton Town       2.11       1.31
# 227       Harrogate Town  Forest Green Rovers       1.64       1.77
# 228        Leyton Orient         Swindon Town       1.18       1.11
# 229       Mansfield Town      Carlisle United       1.15       1.39
# 230       Newport County        Sutton United       3.08       0.85
# 231      Oldham Athletic      Tranmere Rovers       1.61       1.85
# 232            Stevenage    Scunthorpe United       1.28       1.06
# 233              Walsall         Crawley Town       1.51       1.14
# 234        Bradford City    Colchester United       1.74       1.07
# 235    Hartlepool United             Rochdale       1.17       1.42
# 236               Barrow         Swindon Town       1.35       1.05
# 237        Bradford City        Sutton United       1.32       1.63
# 238       Bristol Rovers             Rochdale       2.15       1.58
# 239          Exeter City      Tranmere Rovers       1.93       1.56
# 240       Harrogate Town     Northampton Town       1.29       1.36
# 241    Hartlepool United    Scunthorpe United       1.79       1.12
# 242        Leyton Orient         Crawley Town       1.17       2.11
# 243       Mansfield Town         Salford City       1.21       1.01
# 244       Newport County            Port Vale       1.92       0.56
# 245      Oldham Athletic  Forest Green Rovers       1.97       2.07
# 246            Stevenage      Carlisle United       1.59       1.20
# 247              Walsall    Colchester United       1.81       0.92
# 252             Rochdale       Newport County       2.11       1.72
# 253         Salford City            Stevenage       2.03       1.94
# 255        Sutton United       Harrogate Town       0.86       1.67
# 256      Tranmere Rovers        Leyton Orient       1.41       1.67
# 262       Mansfield Town    Hartlepool United       2.29       0.87
# 265      Oldham Athletic    Scunthorpe United       1.66       1.76
# 267      Tranmere Rovers               Barrow       1.41       0.94
# 268               Barrow      Oldham Athletic       0.83       1.14
# 276         Swindon Town            Stevenage       0.61       1.29
# 278               Barrow        Bradford City       2.08       1.02
# 279         Crawley Town    Colchester United       1.61       2.00
# 280  Forest Green Rovers            Stevenage       2.48       1.01
# 282    Hartlepool United      Oldham Athletic       1.56       1.08
# 285    Scunthorpe United      Carlisle United       1.77       1.74
# 286        Sutton United          Exeter City       1.53       1.03
# 287         Swindon Town     Northampton Town       1.74       1.66
# 288              Walsall       Newport County       2.15       1.56
#
#      home_team_goal_count  away_team_goal_count
# 215                     1                     0
# 216                     1                     2
# 217                     2                     0
# 218                     1                     0
# 219                     2                     0
# 220                     1                     1
# 221                     2                     0
# 222                     1                     1
# 223                     1                     0
# 224                     1                     1
# 225                     1                     2
# 226                     1                     2
# 227                     1                     4
# 228                     4                     1
# 229                     1                     0
# 230                     3                     2
# 231                     0                     1
# 232                     1                     1
# 233                     1                     1
# 234                     0                     0
# 235                     2                     1
# 236                     2                     0
# 237                     2                     2
# 238                     4                     2
# 239                     0                     1
# 240                     1                     2
# 241                     0                     0
# 242                     1                     2
# 243                     2                     1
# 244                     2                     1
# 245                     5                     5
# 246                     0                     2
# 247                     3                     0
# 252                     3                     0
# 253                     1                     0
# 255                     1                     0
# 256                     1                     0
# 262                     3                     2
# 265                     1                     3
# 267                     2                     0
# 268                     0                     0
# 276                     0                     0
# 278                     1                     2
# 279                     3                     1
# 280                     2                     0
# 282                     0                     0
# 285                     0                     1
# 286                     2                     1
# 287                     5                     2
# 288                     3                     3

# %% [markdown]
# # La Liga

# %%
xg_view = laliga_games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[(len(laliga_games) - 50):len(laliga_games)]
# Out:
#            home_team_name        away_team_name  team_a_xg  team_b_xg  \
# 138           Valencia CF        Rayo Vallecano       1.07       1.42
# 139          RCD Mallorca             Getafe CF       1.23       0.97
# 140            Villarreal          FC Barcelona       1.54       1.55
# 141            Real Betis            Levante UD       2.83       1.03
# 142          RCD Espanyol         Real Sociedad       0.93       1.61
# 143                 Cádiz       Atlético Madrid       1.19       2.04
# 144           Real Madrid            Sevilla FC       1.09       1.12
# 145            CA Osasuna              Elche CF       1.92       1.17
# 146           Real Madrid  Athletic Club Bilbao       2.12       1.91
# 147            Granada CF      Deportivo Alavés       1.10       1.59
# 148            Sevilla FC            Villarreal       1.30       1.76
# 149          FC Barcelona            Real Betis       1.76       1.18
# 150       Atlético Madrid          RCD Mallorca       1.36       1.06
# 151         Real Sociedad           Real Madrid       1.10       1.81
# 152        Rayo Vallecano          RCD Espanyol       1.32       1.24
# 153              Elche CF                 Cádiz       1.23       1.67
# 154            Levante UD            CA Osasuna       1.43       1.20
# 155         Celta de Vigo           Valencia CF       1.80       1.39
# 156             Getafe CF  Athletic Club Bilbao       1.67       1.45
# 157          RCD Mallorca         Celta de Vigo       1.25       1.52
# 158          RCD Espanyol            Levante UD       2.04       1.47
# 159      Deportivo Alavés             Getafe CF       1.17       1.28
# 160           Valencia CF              Elche CF       2.39       1.30
# 161  Athletic Club Bilbao            Sevilla FC       1.44       0.73
# 162            Villarreal        Rayo Vallecano       2.02       2.19
# 163            CA Osasuna          FC Barcelona       0.99       1.19
# 164            Real Betis         Real Sociedad       1.39       1.79
# 165           Real Madrid       Atlético Madrid       1.03       1.57
# 166                 Cádiz            Granada CF       1.52       1.85
# 167         Celta de Vigo          RCD Espanyol       1.66       1.08
# 168        Rayo Vallecano      Deportivo Alavés       2.31       1.19
# 169         Real Sociedad            Villarreal       1.34       1.99
# 170          FC Barcelona              Elche CF       2.52       0.83
# 171            Sevilla FC       Atlético Madrid       1.10       1.75
# 172            Granada CF          RCD Mallorca       1.87       1.27
# 173  Athletic Club Bilbao            Real Betis       1.51       2.01
# 174             Getafe CF            CA Osasuna       1.92       1.45
# 175           Real Madrid                 Cádiz       3.94       0.50
# 176            Levante UD           Valencia CF       1.95       1.76
# 177            Villarreal      Deportivo Alavés       2.70       0.87
# 178            Sevilla FC          FC Barcelona       0.86       2.45
# 179            Granada CF       Atlético Madrid       1.09       1.99
# 180  Athletic Club Bilbao           Real Madrid       1.81       1.86
# 181           Valencia CF          RCD Espanyol       1.24       1.64
# 182             Getafe CF           Real Madrid       0.00       0.00
# 183       Atlético Madrid        Rayo Vallecano       0.00       0.00
# 184              Elche CF            Granada CF       0.00       0.00
# 185      Deportivo Alavés         Real Sociedad       0.00       0.00
# 186            Real Betis         Celta de Vigo       0.00       0.00
# 187          RCD Mallorca          FC Barcelona       0.00       0.00
#
#      home_team_goal_count  away_team_goal_count
# 138                     1                     1
# 139                     0                     0
# 140                     1                     3
# 141                     3                     1
# 142                     1                     0
# 143                     1                     4
# 144                     2                     1
# 145                     1                     1
# 146                     1                     0
# 147                     2                     1
# 148                     1                     0
# 149                     0                     1
# 150                     1                     2
# 151                     0                     2
# 152                     1                     0
# 153                     3                     1
# 154                     0                     0
# 155                     1                     2
# 156                     0                     0
# 157                     0                     0
# 158                     4                     3
# 159                     1                     1
# 160                     2                     1
# 161                     0                     1
# 162                     2                     0
# 163                     2                     2
# 164                     4                     0
# 165                     2                     0
# 166                     1                     1
# 167                     3                     1
# 168                     2                     0
# 169                     1                     3
# 170                     3                     2
# 171                     2                     1
# 172                     4                     1
# 173                     3                     2
# 174                     1                     0
# 175                     0                     0
# 176                     3                     4
# 177                     5                     2
# 178                     1                     1
# 179                     2                     1
# 180                     1                     2
# 181                     1                     2
# 182                     1                     0
# 183                     2                     0
# 184                     0                     0
# 185                     1                     1
# 186                     0                     2
# 187                     0                     1

# %% [markdown]
# # Segunda

# %%
xg_view = segunda_games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[(len(segunda_games) - 50):len(segunda_games)]
# Out:
#        home_team_name    away_team_name  team_a_xg  team_b_xg  \
# 190    Sporting Gijón    CF Fuenlabrada       1.67       1.26
# 191           Almería         SD Huesca       1.79       0.93
# 192   Real Valladolid      FC Cartagena       2.18       1.25
# 193           Leganés     UD Las Palmas       1.44       1.21
# 194     SD Amorebieta     Real Zaragoza       1.15       0.91
# 195          UD Ibiza   SD Ponferradina       1.30       1.66
# 196       CD Tenerife  Real Sociedad II       1.42       1.90
# 197          SD Eibar         Girona FC       1.61       1.11
# 198         SD Huesca   Real Valladolid       1.11       2.82
# 199    CF Fuenlabrada           Almería       0.59       0.95
# 200   SD Ponferradina          Mirandés       0.87       1.94
# 201         Málaga CF     SD Amorebieta       1.54       1.09
# 202           CD Lugo          UD Ibiza       1.08       0.56
# 203       Real Oviedo       AD Alcorcón       1.73       0.97
# 204  Real Sociedad II         Burgos CF       1.31       0.92
# 205     UD Las Palmas    Sporting Gijón       1.38       0.75
# 206     Real Zaragoza          SD Eibar       1.34       1.23
# 207      FC Cartagena       CD Tenerife       1.29       1.19
# 208         Girona FC           Leganés       1.39       1.61
# 209    Sporting Gijón         SD Huesca       1.94       1.13
# 210          UD Ibiza         Girona FC       1.72       1.10
# 211         Burgos CF    CF Fuenlabrada       1.18       1.16
# 212           Almería     Real Zaragoza       1.85       0.48
# 213          SD Eibar         Málaga CF       1.36       1.40
# 214       CD Tenerife           CD Lugo       1.06       1.61
# 215           Leganés   SD Ponferradina       1.27       1.26
# 216   Real Valladolid       Real Oviedo       1.23       0.73
# 217       AD Alcorcón      FC Cartagena       1.63       1.41
# 218     SD Amorebieta     UD Las Palmas       1.31       2.22
# 219          Mirandés  Real Sociedad II       0.85       1.26
# 220         Girona FC         Burgos CF       1.57       1.71
# 221          UD Ibiza    Sporting Gijón       2.90       1.13
# 222         Málaga CF           Leganés       0.85       1.97
# 223     UD Las Palmas          SD Eibar       1.99       1.18
# 224    CF Fuenlabrada       Real Oviedo       1.09       0.89
# 225   SD Ponferradina     SD Amorebieta       1.37       1.46
# 226     Real Zaragoza       CD Tenerife       1.32       0.85
# 227         SD Huesca       AD Alcorcón       1.28       1.21
# 228  Real Sociedad II   Real Valladolid       1.31       2.02
# 229      FC Cartagena          Mirandés       1.04       1.11
# 231       Real Oviedo   SD Ponferradina       2.06       0.71
# 232         Burgos CF     SD Amorebieta       1.80       1.67
# 233          SD Eibar  Real Sociedad II       1.78       1.40
# 234   Real Valladolid           Leganés       0.00       0.00
# 235           Almería      FC Cartagena       0.00       0.00
# 236    Sporting Gijón           CD Lugo       0.00       0.00
# 237         SD Huesca         Girona FC       0.00       0.00
# 238          Mirandés     Real Zaragoza       0.00       0.00
# 239    CF Fuenlabrada          UD Ibiza       0.00       0.00
# 240       CD Tenerife     UD Las Palmas       0.00       0.00
#
#      home_team_goal_count  away_team_goal_count
# 190                     1                     1
# 191                     0                     0
# 192                     2                     0
# 193                     4                     1
# 194                     1                     1
# 195                     0                     1
# 196                     2                     0
# 197                     4                     2
# 198                     3                     2
# 199                     1                     1
# 200                     2                     1
# 201                     1                     2
# 202                     0                     0
# 203                     3                     1
# 204                     0                     1
# 205                     1                     0
# 206                     1                     0
# 207                     1                     1
# 208                     3                     0
# 209                     1                     1
# 210                     1                     1
# 211                     2                     0
# 212                     3                     0
# 213                     2                     2
# 214                     1                     1
# 215                     1                     1
# 216                     2                     1
# 217                     1                     1
# 218                     1                     1
# 219                     2                     0
# 220                     3                     1
# 221                     0                     2
# 222                     0                     2
# 223                     0                     1
# 224                     0                     0
# 225                     1                     1
# 226                     0                     2
# 227                     0                     0
# 228                     0                     2
# 229                     3                     0
# 231                     2                     0
# 232                     2                     2
# 233                     3                     2
# 234                     1                     0
# 235                     0                     1
# 236                     1                     1
# 237                     0                     1
# 238                     2                     0
# 239                     1                     2
# 240                     0                     1
