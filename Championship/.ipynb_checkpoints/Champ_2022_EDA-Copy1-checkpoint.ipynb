# %% [markdown]
# # 2022 Championship EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
team_stats = pd.read_csv('../../footy_data/england-championship-teams-2021-to-2022-stats.csv')
games = pd.read_csv('../../footy_data/england-championship-matches-2021-to-2022-stats.csv')
# league = pd.read_csv('../../footy_data/championship_league_2022.csv')

# %%
games_for_later = games

# %%
league[['goals_min_0_to_10', 'goals_min_11_to_20', 'goals_min_21_to_30',
       'goals_min_31_to_40', 'goals_min_41_to_50', 'goals_min_51_to_60',
       'goals_min_61_to_70', 'goals_min_71_to_80', 'goals_min_81_to_90',
       'goals_min_0_to_15', 'goals_min_16_to_30', 'goals_min_31_to_45',
       'goals_min_46_to_60', 'goals_min_61_to_75', 'goals_min_76_to_90',
       'xg_avg_per_match']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5e5ab8764ae4> in <module>
# ----> 1 league[['goals_min_0_to_10', 'goals_min_11_to_20', 'goals_min_21_to_30',
#       2        'goals_min_31_to_40', 'goals_min_41_to_50', 'goals_min_51_to_60',
#       3        'goals_min_61_to_70', 'goals_min_71_to_80', 'goals_min_81_to_90',
#       4        'goals_min_0_to_15', 'goals_min_16_to_30', 'goals_min_31_to_45',
#       5        'goals_min_46_to_60', 'goals_min_61_to_75', 'goals_min_76_to_90',
#
# NameError: name 'league' is not defined

# %%
games = games.loc[games['status'] == 'complete']
games
#Played matches
# Out:
#       timestamp               date_GMT    status  attendance  \
# 0    1628275500   Aug 06 2021 - 6:45pm  complete         NaN
# 1    1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# 2    1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# 3    1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# 4    1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# ..          ...                    ...       ...         ...
# 163  1634997600   Oct 23 2021 - 2:00pm  complete         NaN
# 164  1634997600   Oct 23 2021 - 2:00pm  complete         NaN
# 165  1634997600   Oct 23 2021 - 2:00pm  complete         NaN
# 166  1635075000  Oct 24 2021 - 11:30am  complete         NaN
# 167  1635084000   Oct 24 2021 - 2:00pm  complete         NaN
#
#            home_team_name        away_team_name           referee  Game Week  \
# 0         AFC Bournemouth  West Bromwich Albion   Dean Whitestone          1
# 1        Blackburn Rovers          Swansea City        David Webb          1
# 2            Bristol City             Blackpool       Andy Davies          1
# 3            Cardiff City              Barnsley      Steve Martin          1
# 4            Derby County     Huddersfield Town  Geoff Eltringham          1
# ..                    ...                   ...               ...        ...
# 163              Millwall            Stoke City       Andy Davies         14
# 164   Peterborough United   Queens Park Rangers    Jarred Gillett         14
# 165  West Bromwich Albion          Bristol City      Joshua Smith         14
# 166              Barnsley      Sheffield United        Gavin Ward         14
# 167     Nottingham Forest                Fulham   James Linington         14
#
#      Pre-Match PPG (Home)  Pre-Match PPG (Away)  ...  odds_ft_home_team_win  \
# 0                    0.00                  0.00  ...                   2.30
# 1                    0.00                  0.00  ...                   2.20
# 2                    0.00                  0.00  ...                   2.20
# 3                    0.00                  0.00  ...                   2.50
# 4                    0.00                  0.00  ...                   2.60
# ..                    ...                   ...  ...                    ...
# 163                  1.33                  0.83  ...                   2.42
# 164                  1.33                  1.17  ...                   3.00
# 165                  2.33                  2.00  ...                   1.71
# 166                  0.83                  0.83  ...                   3.10
# 167                  0.67                  1.67  ...                   3.80
#
#      odds_ft_draw  odds_ft_away_team_win  odds_ft_over15  odds_ft_over25  \
# 0            3.40                   3.10            1.33            1.85
# 1            3.25                   3.60            1.38            2.15
# 2            3.35                   3.45            1.39            2.10
# 3            3.20                   3.00            1.45            2.25
# 4            3.35                   2.80            1.43            2.15
# ..            ...                    ...             ...             ...
# 163          3.25                   3.05            1.44            2.25
# 164          3.25                   2.45            1.30            1.94
# 165          3.70                   5.20            1.33            2.01
# 166          3.30                   2.30            1.40            2.02
# 167          3.40                   2.00            1.33            1.88
#
#      odds_ft_over35  odds_ft_over45  odds_btts_yes odds_btts_no  \
# 0              3.15            6.00           1.80         2.05
# 1              3.65            7.25           1.95         1.87
# 2              3.45            6.75           1.95         1.91
# 3              3.85            7.50           1.95         1.91
# 4              3.70            7.00           1.95         1.87
# ..              ...             ...            ...          ...
# 163            4.50            9.50           1.98         1.83
# 164            3.40            6.50           1.73         2.00
# 165            3.60            7.00           2.00         1.73
# 166            4.00            8.00           1.83         1.83
# 167            3.60            7.00           1.83         1.83
#
#                                       stadium_name
# 0           Vitality Stadium (Bournemouth- Dorset)
# 1               Ewood Park (Blackburn- Lancashire)
# 2                            Ashton Gate (Bristol)
# 3        Cardiff City Stadium (Cardiff (Caerdydd))
# 4                       Pride Park Stadium (Derby)
# ..                                             ...
# 163                               The Den (London)
# 164            Weston Homes Stadium (Peterborough)
# 165                  The Hawthorns (West Bromwich)
# 166            Oakwell (Barnsley- South Yorkshire)
# 167  The City Ground (Nottingham- Nottinghamshire)
#
# [168 rows x 64 columns]

# %% [markdown]
# # Make new column for new xG data

# %%
games['avg_home_xg_for_home_team'] = ""
games['avg_away_xg_against_home_team'] = ""
games['avg_xg_for_home_team'] = ""
games['avg_xg_against_home_team'] = ""
games['avg_home_xg_for_away_team'] = ""
games['avg_away_xg_against_away_team'] = ""
games['avg_xg_for_away_team'] = ""
games['avg_xg_against_away_team'] = ""
# Out:
# <ipython-input-6-4acc3b60a5d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games['avg_home_xg_for_home_team'] = ""
# <ipython-input-6-4acc3b60a5d7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games['avg_away_xg_against_home_team'] = ""
# <ipython-input-6-4acc3b60a5d7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games['avg_xg_for_home_team'] = ""
# <ipython-input-6-4acc3b60a5d7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games['avg_xg_against_home_team'] = ""
# <ipython-input-6-4acc3b60a5d7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games['avg_home_xg_for_away_team'] = ""
# <ipython-input-6-4acc3b60a5d7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games['avg_away_xg_against_away_team'] = ""
# <ipython-input-6-4acc3b60a5d7>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games['avg_xg_for_away_team'] = ""
# <ipython-input-6-4acc3b60a5d7>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games['avg_xg_against_away_team'] = ""

# %% [markdown]
# # Get average xG for a team at home

# %%
def xg_for_home(team):
    avg_for_home = games.loc[games['home_team_name'] == team_stats[team]]

# %% [markdown]
# # Get average xG for a team away

# %%
#CODE TO FIX XG AND XGA HERE
#average of home_team = common_name[0]xgfor and away_team = common_name[0] xgfor
def get_avg_xg(team):
    avg_for = games.loc[games['home_team_name'] == team_stats[team]
    avg_for = avg_stoke.append(games.loc[games['away_team_name'] == team_stats['common_name'][0]])
# Out:
#   File "<ipython-input-8-9d8c8bfe7570>", line 5
#     avg_for = avg_stoke.append(games.loc[games['away_team_name'] == team_stats['common_name'][0]])
#     ^
# SyntaxError: invalid syntax

# %%
xg_view = games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[130:175]
# Out:
#            home_team_name        away_team_name  team_a_xg  team_b_xg  \
# 130   Peterborough United          Bristol City       1.65       1.85
# 131   Queens Park Rangers     Preston North End       2.02       1.37
# 132  West Bromwich Albion       Birmingham City       1.48       1.12
# 133                Fulham   Queens Park Rangers       1.74       1.08
# 134      Blackburn Rovers         Coventry City       1.49       1.48
# 135          Bristol City       AFC Bournemouth       0.79       2.46
# 136     Huddersfield Town             Hull City       1.54       1.24
# 137         Middlesbrough   Peterborough United       1.85       0.69
# 138              Millwall            Luton Town       1.86       0.98
# 139     Nottingham Forest             Blackpool       1.53       0.80
# 140     Preston North End          Derby County       1.02       2.10
# 141               Reading              Barnsley       1.46       2.11
# 142      Sheffield United            Stoke City       1.73       1.35
# 143          Swansea City          Cardiff City       1.65       1.22
# 144          Bristol City     Nottingham Forest       0.89       1.64
# 145          Derby County            Luton Town       1.10       1.14
# 146   Queens Park Rangers      Blackburn Rovers       1.74       0.77
# 147      Sheffield United              Millwall       1.25       1.57
# 148            Stoke City       AFC Bournemouth       1.23       1.41
# 149                Fulham          Cardiff City       2.16       1.50
# 150     Huddersfield Town       Birmingham City       1.16       1.01
# 151             Hull City   Peterborough United       2.29       1.29
# 152         Middlesbrough              Barnsley       2.48       1.35
# 153     Preston North End         Coventry City       1.79       1.11
# 154          Swansea City  West Bromwich Albion       1.15       1.32
# 155               Reading             Blackpool       0.97       2.54
# 156          Cardiff City         Middlesbrough       1.07       2.47
# 157       AFC Bournemouth     Huddersfield Town       1.90       0.67
# 158       Birmingham City          Swansea City       1.58       1.02
# 159      Blackburn Rovers               Reading       1.46       1.60
# 160             Blackpool     Preston North End       1.37       1.20
# 161         Coventry City          Derby County       1.32       1.01
# 162            Luton Town             Hull City       1.67       1.37
# 163              Millwall            Stoke City       1.21       1.51
# 164   Peterborough United   Queens Park Rangers       1.84       1.97
# 165  West Bromwich Albion          Bristol City       2.71       1.01
# 166              Barnsley      Sheffield United       1.46       1.49
# 167     Nottingham Forest                Fulham       1.10       1.38
#
#      home_team_goal_count  away_team_goal_count
# 130                     2                     3
# 131                     3                     2
# 132                     1                     0
# 133                     4                     1
# 134                     2                     2
# 135                     0                     2
# 136                     2                     0
# 137                     2                     0
# 138                     0                     2
# 139                     2                     1
# 140                     0                     0
# 141                     1                     0
# 142                     2                     1
# 143                     3                     0
# 144                     1                     2
# 145                     2                     2
# 146                     1                     0
# 147                     1                     2
# 148                     0                     1
# 149                     2                     0
# 150                     0                     0
# 151                     1                     2
# 152                     2                     0
# 153                     2                     1
# 154                     2                     1
# 155                     2                     3
# 156                     0                     2
# 157                     3                     0
# 158                     2                     1
# 159                     2                     0
# 160                     2                     0
# 161                     1                     1
# 162                     1                     0
# 163                     2                     1
# 164                     2                     1
# 165                     3                     0
# 166                     2                     3
# 167                     0                     4

# %%
team_stats['common_name'][0]
# Out:
# 'Stoke City'

# %% [markdown]
# # Goal Analysis

# %%
season_goal_total = games['total_goal_count'].sum()
season_1h_goal_total = games['total_goals_at_half_time'].sum()
percent_goals_1h = ((season_1h_goal_total)/(season_goal_total)) * 100

# %%
print(f'There were {season_goal_total} goals scored this season')

# %%
print(f'There were {season_1h_goal_total} goals scored in the 1H this season, ')

# %%
season_1h_goal_total

# %%
round(season_1h_goal_total/season_goal_total, 2)
#% of first half goals

# %%
games['total_goals_at_half_time'].value_counts()

# %% [markdown]
# # Adding more columns

# %%
games['home_xg'] = ""
games['away_xg'] = ""
games['home_xg_against'] = ""
games['away_xg_against'] = ""
games['home_total_corners'] = ""
games['away_total_corners'] = ""

# Creating new columns where our data will go

# %% [markdown]
# Let's write a function to help fill xg in our games df

# %%
xg_stats = team_stats[['common_name', 'xg_for_avg_overall']]
corner_stats = team_stats[['common_name', 'corners_per_match']]
xga_stats = team_stats[['common_name', 'xg_against_avg_overall']]

xga_stats

# %%
xg_stats = dict(xg_stats.values)
corner_stats = dict(corner_stats.values)
xga_stats = dict(xga_stats.values)

#By making this into dictionaries, it will be easier to call them/update them with the function

# %%
def fill_stats(team):
    games['home_xg'] = np.where(games['home_team_name'] == team, xg_stats[team], games['home_xg'])
    games['away_xg'] = np.where(games['away_team_name'] == team, xg_stats[team], games['away_xg'])
    games['home_xg_against'] = np.where(games['home_team_name'] == team, xga_stats[team], games['home_xg_against'])
    games['away_xg_against'] = np.where(games['away_team_name'] == team, xga_stats[team], games['away_xg_against'])
    games['home_total_corners'] = np.where(games['home_team_name'] == team, corner_stats[team], games['home_total_corners'])
    games['away_total_corners'] = np.where(games['away_team_name'] == team, corner_stats[team], games['away_total_corners'])
    
#Function to put team stats into games dataframe

# %%
fill_stats(team_stats['common_name'][0])
fill_stats(team_stats['common_name'][1])
fill_stats(team_stats['common_name'][2]) 
fill_stats(team_stats['common_name'][3]) 
fill_stats(team_stats['common_name'][4]) 
fill_stats(team_stats['common_name'][5]) 
fill_stats(team_stats['common_name'][6]) 
fill_stats(team_stats['common_name'][7]) 
fill_stats(team_stats['common_name'][8]) 
fill_stats(team_stats['common_name'][9]) 
fill_stats(team_stats['common_name'][10]) 
fill_stats(team_stats['common_name'][11]) 
fill_stats(team_stats['common_name'][12]) 
fill_stats(team_stats['common_name'][13]) 
fill_stats(team_stats['common_name'][14]) 
fill_stats(team_stats['common_name'][15]) 
fill_stats(team_stats['common_name'][16]) 
fill_stats(team_stats['common_name'][17]) 
fill_stats(team_stats['common_name'][18]) 
fill_stats(team_stats['common_name'][19]) 
fill_stats(team_stats['common_name'][20]) 
fill_stats(team_stats['common_name'][21]) 
fill_stats(team_stats['common_name'][22]) 
fill_stats(team_stats['common_name'][23])

# %%
# fill_stats('Fulham')
# fill_stats('Blackburn Rovers')
# fill_stats('West Bromwich Albion')
# fill_stats('Queens Park Rangers')
# fill_stats('AFC Bournemouth')
# fill_stats('Middlesbrough')
# fill_stats('Barnsley')
# fill_stats('Millwall')
# fill_stats('Sheffield United')
# fill_stats('Reading')
# fill_stats('Cardiff City')
# fill_stats('Nottingham Forest')
# fill_stats('Hull City')
# fill_stats('Blackpool')
# fill_stats('Luton Town')
# fill_stats('Stoke City')
# fill_stats('Swansea City')
# fill_stats('Derby County')
# fill_stats('Huddersfield Town')
# fill_stats('Preston North End')
# fill_stats('Coventry City')
# fill_stats('Peterborough United')
# fill_stats('Birmingham City')
# fill_stats('Bristol City')

#Reading in stats

# %% [markdown]
# # Some more EDA

# %% [markdown]
# Let's write a function to help fill xg in our games df

# %%
games['home_xg'] = ""
games['away_xg'] = ""
games['home_xg_against'] = ""
games['away_xg_against'] = ""
games['home_total_corners'] = ""
games['away_total_corners'] = ""

# Creating new columns where our data will go



xg_stats = team_stats[['common_name', 'xg_for_avg_overall']]
corner_stats = team_stats[['common_name', 'corners_per_match']]
xga_stats = team_stats[['common_name', 'xg_against_avg_overall']]

xga_stats.head()

xg_stats = dict(xg_stats.values)
corner_stats = dict(corner_stats.values)
xga_stats = dict(xga_stats.values)

#By making this into dictionaries, it will be easier to call them/update them with the function

def fill_stats(team):
    games['home_xg'] = np.where(games['home_team_name'] == team, xg_stats[team], games['home_xg'])
    games['away_xg'] = np.where(games['away_team_name'] == team, xg_stats[team], games['away_xg'])
    games['home_xg_against'] = np.where(games['home_team_name'] == team, xga_stats[team], games['home_xg_against'])
    games['away_xg_against'] = np.where(games['away_team_name'] == team, xga_stats[team], games['away_xg_against'])
    games['home_total_corners'] = np.where(games['home_team_name'] == team, corner_stats[team], games['home_total_corners'])
    games['away_total_corners'] = np.where(games['away_team_name'] == team, corner_stats[team], games['away_total_corners'])
    
#Function to put team stats into games dataframe

fill_stats('Fulham')
fill_stats('Blackburn Rovers')
fill_stats('West Bromwich Albion')
fill_stats('Queens Park Rangers')
fill_stats('AFC Bournemouth')
fill_stats('Middlesbrough')
fill_stats('Barnsley')
fill_stats('Millwall')
fill_stats('Sheffield United')
fill_stats('Reading')
fill_stats('Cardiff City')
fill_stats('Nottingham Forest')
fill_stats('Hull City')
fill_stats('Blackpool')
fill_stats('Luton Town')
fill_stats('Stoke City')
fill_stats('Swansea City')
fill_stats('Derby County')
fill_stats('Huddersfield Town')
fill_stats('Preston North End')
fill_stats('Coventry City')
fill_stats('Peterborough United')
fill_stats('Birmingham City')
fill_stats('Bristol City')

#Reading in stats

# Some more EDA

# %% [markdown]
# # Over/Under 2.5?

# %%
games['over/under'] = np.where(games['home_team_goal_count'] + games['away_team_goal_count'] > 2.5, 1, 0)
# Adding column 0 represents under 2.5, 1 represents over 2.5

# %%
games['over/under'].value_counts()

# %% [markdown]
# # xG Over/Under 2.5?

# %%
games['xg_over/under'] = np.where(games['team_a_xg'] + games['team_b_xg'] > 2.99, 1, 0)
# Adding column 0 represents under 2.5, 1 represents over 2.5
games['xg_over/under_1.99'] = np.where(games['team_a_xg'] + games['team_b_xg'] > 1.99, 1, 0)
# Adding column 0 represents under 1.5, 1 represents over 1.5

# %%
games['xg_over/under'].value_counts()

# %%
games['xg_over/under_1.99'].value_counts()

# %% [markdown]
# # First Week

# %%
games['over/under_1.5'] = np.where(games['home_team_goal_count'] + games['away_team_goal_count'] > 1.5, 1, 0)
# Adding column 0 represents under 1.5, 1 represents over 1.5

# %%
first_matchweek = games[0:12]

# %%
first_matchweek['over/under'].value_counts()

# %%
first_matchweek['over/under_1.5'].value_counts()

# %%
first_matchweek['xg_over/under'].value_counts()

# %%
first_matchweek['xg_over/under_1.99'].value_counts()

# %%
games['home_team_goal_count_half_time'].sum()

# %%
games['away_team_goal_count_half_time'].sum()
# Out:
# 60
