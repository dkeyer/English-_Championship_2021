# %% [markdown]
# # 2022 Championship EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, RidgeCV, Lasso, \
LassoCV, ElasticNet, ElasticNetCV
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.neighbors import KNeighborsClassifier

# %%
team_stats = pd.read_csv('../footy_data/championship_teams_2022.csv')
games = pd.read_csv('../footy_data/championship_games_2022.csv')

# %%
games = games.loc[games['status'] == 'complete']
games
#Played matches
# Out:
#      timestamp              date_GMT    status  attendance     home_team_name  \
# 0   1628275500  Aug 06 2021 - 6:45pm  complete         NaN    AFC Bournemouth
# 1   1628344800  Aug 07 2021 - 2:00pm  complete         NaN   Blackburn Rovers
# 2   1628344800  Aug 07 2021 - 2:00pm  complete         NaN       Bristol City
# 3   1628344800  Aug 07 2021 - 2:00pm  complete         NaN       Cardiff City
# 4   1628344800  Aug 07 2021 - 2:00pm  complete         NaN       Derby County
# ..         ...                   ...       ...         ...                ...
# 79  1631731500  Sep 15 2021 - 6:45pm  complete         NaN       Bristol City
# 80  1631731500  Sep 15 2021 - 6:45pm  complete         NaN      Coventry City
# 81  1631731500  Sep 15 2021 - 6:45pm  complete         NaN  Nottingham Forest
# 82  1631731500  Sep 15 2021 - 6:45pm  complete         NaN       Swansea City
# 83  1631731500  Sep 15 2021 - 6:45pm  complete         NaN         Stoke City
#
#           away_team_name            referee  Game Week  Pre-Match PPG (Home)  \
# 0   West Bromwich Albion    Dean Whitestone          1                  0.00
# 1           Swansea City         David Webb          1                  0.00
# 2              Blackpool        Andy Davies          1                  0.00
# 3               Barnsley       Steve Martin          1                  0.00
# 4      Huddersfield Town   Geoff Eltringham          1                  0.00
# ..                   ...                ...        ...                   ...
# 79            Luton Town     Jeremy Simpson          7                  0.67
# 80          Cardiff City  Michael Salisbury          7                  3.00
# 81         Middlesbrough       Andy Woolmer          7                  0.00
# 82              Millwall         John Busby          7                  0.67
# 83              Barnsley      Leigh Doughty          7                  3.00
#
#     Pre-Match PPG (Away)  ...  odds_ft_home_team_win  odds_ft_draw  \
# 0                   0.00  ...                   2.30          3.40
# 1                   0.00  ...                   2.20          3.25
# 2                   0.00  ...                   2.20          3.35
# 3                   0.00  ...                   2.50          3.20
# 4                   0.00  ...                   2.60          3.35
# ..                   ...  ...                    ...           ...
# 79                  1.33  ...                   2.35          3.15
# 80                  2.33  ...                   2.30          3.30
# 81                  0.67  ...                   2.90          3.00
# 82                  0.67  ...                   2.65          3.05
# 83                  0.67  ...                   1.71          3.65
#
#     odds_ft_away_team_win  odds_ft_over15  odds_ft_over25  odds_ft_over35  \
# 0                    3.10            1.33            1.85            3.15
# 1                    3.60            1.38            2.15            3.65
# 2                    3.45            1.39            2.10            3.45
# 3                    3.00            1.45            2.25            3.85
# 4                    2.80            1.43            2.15            3.70
# ..                    ...             ...             ...             ...
# 79                   3.40            1.50            2.35            4.15
# 80                   3.30            1.40            2.10            3.55
# 81                   2.75            1.53            2.45            4.25
# 82                   2.95            1.54            2.45            4.45
# 83                   5.50            1.39            2.20            3.90
#
#     odds_ft_over45  odds_btts_yes odds_btts_no  \
# 0             6.00           1.80         2.05
# 1             7.25           1.95         1.87
# 2             6.75           1.95         1.91
# 3             7.50           1.95         1.91
# 4             7.00           1.95         1.87
# ..             ...            ...          ...
# 79            8.25           2.10         1.77
# 80            6.75           1.91         1.91
# 81            8.50           2.10         1.74
# 82            8.75           2.15         1.71
# 83            7.50           2.00         1.87
#
#                                          stadium_name
# 0              Vitality Stadium (Bournemouth- Dorset)
# 1                  Ewood Park (Blackburn- Lancashire)
# 2                               Ashton Gate (Bristol)
# 3           Cardiff City Stadium (Cardiff (Caerdydd))
# 4                          Pride Park Stadium (Derby)
# ..                                                ...
# 79                              Ashton Gate (Bristol)
# 80  The Coventry Building Society Arena (Coventry-...
# 81      The City Ground (Nottingham- Nottinghamshire)
# 82                      Swansea.com Stadium (Swansea)
# 83     bet365 Stadium (Stoke-on-Trent- Staffordshire)
#
# [84 rows x 64 columns]

# %%
#CODE TO FIX XG AND XGA HERE
#average of home_team = common_name[0]xgfor and away_team = common_name[0] xgfor

# %%
xg_view = games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[48:84]
# Out:
#           home_team_name        away_team_name  team_a_xg  team_b_xg  \
# 48          Cardiff City          Bristol City       1.76       1.38
# 49          Derby County     Nottingham Forest       1.55       1.54
# 50              Barnsley       Birmingham City       0.96       1.71
# 51                Fulham            Stoke City       1.87       1.33
# 52     Huddersfield Town               Reading       1.88       1.01
# 53             Hull City       AFC Bournemouth       0.56       1.24
# 54            Luton Town      Sheffield United       1.27       1.38
# 55         Middlesbrough      Blackburn Rovers       1.60       0.78
# 56              Millwall             Blackpool       2.47       0.99
# 57     Preston North End          Swansea City       1.62       0.72
# 58   Queens Park Rangers         Coventry City       1.56       1.69
# 59   Peterborough United  West Bromwich Albion       0.48       1.66
# 60       Birmingham City          Derby County       1.38       0.90
# 61       AFC Bournemouth              Barnsley       2.06       0.41
# 62      Blackburn Rovers            Luton Town       1.20       1.46
# 63             Blackpool                Fulham       0.99       1.87
# 64          Bristol City     Preston North End       1.47       1.20
# 65         Coventry City         Middlesbrough       1.79       1.21
# 66               Reading   Queens Park Rangers       1.37       2.10
# 67      Sheffield United   Peterborough United       2.70       1.23
# 68            Stoke City     Huddersfield Town       1.06       1.51
# 69          Swansea City             Hull City       1.50       0.66
# 70  West Bromwich Albion              Millwall       1.48       1.45
# 71     Nottingham Forest          Cardiff City       0.90       1.85
# 72       AFC Bournemouth   Queens Park Rangers       1.26       1.70
# 73      Blackburn Rovers             Hull City       1.75       1.94
# 74             Blackpool     Huddersfield Town       1.66       1.46
# 75      Sheffield United     Preston North End       1.73       1.46
# 76               Reading   Peterborough United       1.52       1.13
# 77  West Bromwich Albion          Derby County       2.87       0.79
# 78       Birmingham City                Fulham       2.11       1.83
# 79          Bristol City            Luton Town       1.50       2.01
# 80         Coventry City          Cardiff City       1.43       1.23
# 81     Nottingham Forest         Middlesbrough       1.47       1.64
# 82          Swansea City              Millwall       1.13       1.38
# 83            Stoke City              Barnsley       1.71       1.25
#
#     home_team_goal_count  away_team_goal_count
# 48                     1                     2
# 49                     1                     1
# 50                     1                     1
# 51                     3                     0
# 52                     4                     0
# 53                     0                     0
# 54                     0                     0
# 55                     1                     1
# 56                     2                     1
# 57                     3                     1
# 58                     2                     0
# 59                     0                     1
# 60                     2                     0
# 61                     3                     0
# 62                     2                     2
# 63                     1                     0
# 64                     0                     0
# 65                     2                     0
# 66                     3                     3
# 67                     6                     2
# 68                     2                     1
# 69                     0                     0
# 70                     1                     1
# 71                     1                     2
# 72                     2                     1
# 73                     2                     0
# 74                     0                     3
# 75                     2                     2
# 76                     3                     1
# 77                     0                     0
# 78                     1                     4
# 79                     1                     1
# 80                     1                     0
# 81                     0                     2
# 82                     0                     0
# 83                     1                     1

# %%
team_stats['common_name'][0]
# Out:
# 'West Bromwich Albion'

# %% [markdown]
# # Goal Analysis

# %%
season_goal_total = games['total_goal_count'].sum()
season_1h_goal_total = games['total_goals_at_half_time'].sum()
percent_goals_1h = ((season_1h_goal_total)/(season_goal_total)) * 100

# %%
print(f'There were {season_goal_total} goals scored this season')
# Out:
# There were 190 goals scored this season

# %%
print(f'There were {season_1h_goal_total} goals scored in the 1H this season, ')
# Out:
# There were 71 goals scored in the 1H this season,

# %%
season_1h_goal_total
# Out:
# 71

# %%
round(season_1h_goal_total/season_goal_total, 2)
#% of first half goals
# Out:
# 0.37

# %%
games['total_goals_at_half_time'].value_counts()
# Out:
# 1    26
# 0    26
# 2    16
# 3     3
# 4     1
# Name: total_goals_at_half_time, dtype: int64

# %% [markdown]
# # Adding more columns

# %%
games['home_xg'] = ""
games['away_xg'] = ""
games['home_xg_against'] = ""
games['away_xg_against'] = ""
games['home_total_corners'] = ""
games['away_total_corners'] = ""

# Creating new columns where our data will go

# %% [markdown]
# Let's write a function to help fill xg in our games df

# %%
xg_stats = team_stats[['common_name', 'xg_for_avg_overall']]
corner_stats = team_stats[['common_name', 'corners_per_match']]
xga_stats = team_stats[['common_name', 'xg_against_avg_overall']]

xga_stats
# Out:
#              common_name  xg_against_avg_overall
# 0             Stoke City                    0.96
# 1   West Bromwich Albion                    0.70
# 2          Middlesbrough                    0.99
# 3        AFC Bournemouth                    0.97
# 4              Hull City                    1.15
# 5           Swansea City                    1.17
# 6    Queens Park Rangers                    1.21
# 7           Cardiff City                    0.83
# 8                 Fulham                    0.72
# 9        Birmingham City                    0.81
# 10          Bristol City                    0.97
# 11     Preston North End                    0.93
# 12     Nottingham Forest                    1.18
# 13          Derby County                    1.16
# 14              Barnsley                    1.24
# 15      Blackburn Rovers                    1.26
# 16     Huddersfield Town                    1.15
# 17               Reading                    1.54
# 18             Blackpool                    1.48
# 19              Millwall                    1.10
# 20         Coventry City                    0.95
# 21   Peterborough United                    1.39
# 22      Sheffield United                    0.82
# 23            Luton Town                    1.20

# %%
xg_stats = dict(xg_stats.values)
corner_stats = dict(corner_stats.values)
xga_stats = dict(xga_stats.values)

#By making this into dictionaries, it will be easier to call them/update them with the function

# %%
def fill_stats(team):
    games['home_xg'] = np.where(games['home_team_name'] == team, xg_stats[team], games['home_xg'])
    games['away_xg'] = np.where(games['away_team_name'] == team, xg_stats[team], games['away_xg'])
    games['home_xg_against'] = np.where(games['home_team_name'] == team, xga_stats[team], games['home_xg_against'])
    games['away_xg_against'] = np.where(games['away_team_name'] == team, xga_stats[team], games['away_xg_against'])
    games['home_total_corners'] = np.where(games['home_team_name'] == team, corner_stats[team], games['home_total_corners'])
    games['away_total_corners'] = np.where(games['away_team_name'] == team, corner_stats[team], games['away_total_corners'])
    
#Function to put team stats into games dataframe

# %%
fill_stats(team_stats['common_name'][0])
fill_stats(team_stats['common_name'][1])
fill_stats(team_stats['common_name'][2]) 
fill_stats(team_stats['common_name'][3]) 
fill_stats(team_stats['common_name'][4]) 
fill_stats(team_stats['common_name'][5]) 
fill_stats(team_stats['common_name'][6]) 
fill_stats(team_stats['common_name'][7]) 
fill_stats(team_stats['common_name'][8]) 
fill_stats(team_stats['common_name'][9]) 
fill_stats(team_stats['common_name'][10]) 
fill_stats(team_stats['common_name'][11]) 
fill_stats(team_stats['common_name'][12]) 
fill_stats(team_stats['common_name'][13]) 
fill_stats(team_stats['common_name'][14]) 
fill_stats(team_stats['common_name'][15]) 
fill_stats(team_stats['common_name'][16]) 
fill_stats(team_stats['common_name'][17]) 
fill_stats(team_stats['common_name'][18]) 
fill_stats(team_stats['common_name'][19]) 
fill_stats(team_stats['common_name'][20]) 
fill_stats(team_stats['common_name'][21]) 
fill_stats(team_stats['common_name'][22]) 
fill_stats(team_stats['common_name'][23])

# %%
# fill_stats('Fulham')
# fill_stats('Blackburn Rovers')
# fill_stats('West Bromwich Albion')
# fill_stats('Queens Park Rangers')
# fill_stats('AFC Bournemouth')
# fill_stats('Middlesbrough')
# fill_stats('Barnsley')
# fill_stats('Millwall')
# fill_stats('Sheffield United')
# fill_stats('Reading')
# fill_stats('Cardiff City')
# fill_stats('Nottingham Forest')
# fill_stats('Hull City')
# fill_stats('Blackpool')
# fill_stats('Luton Town')
# fill_stats('Stoke City')
# fill_stats('Swansea City')
# fill_stats('Derby County')
# fill_stats('Huddersfield Town')
# fill_stats('Preston North End')
# fill_stats('Coventry City')
# fill_stats('Peterborough United')
# fill_stats('Birmingham City')
# fill_stats('Bristol City')

#Reading in stats

# %% [markdown]
# # Some more EDA

# %% [markdown]
# Let's write a function to help fill xg in our games df

# %%
games['home_xg'] = ""
games['away_xg'] = ""
games['home_xg_against'] = ""
games['away_xg_against'] = ""
games['home_total_corners'] = ""
games['away_total_corners'] = ""

# Creating new columns where our data will go



xg_stats = team_stats[['common_name', 'xg_for_avg_overall']]
corner_stats = team_stats[['common_name', 'corners_per_match']]
xga_stats = team_stats[['common_name', 'xg_against_avg_overall']]

xga_stats.head()

xg_stats = dict(xg_stats.values)
corner_stats = dict(corner_stats.values)
xga_stats = dict(xga_stats.values)

#By making this into dictionaries, it will be easier to call them/update them with the function

def fill_stats(team):
    games['home_xg'] = np.where(games['home_team_name'] == team, xg_stats[team], games['home_xg'])
    games['away_xg'] = np.where(games['away_team_name'] == team, xg_stats[team], games['away_xg'])
    games['home_xg_against'] = np.where(games['home_team_name'] == team, xga_stats[team], games['home_xg_against'])
    games['away_xg_against'] = np.where(games['away_team_name'] == team, xga_stats[team], games['away_xg_against'])
    games['home_total_corners'] = np.where(games['home_team_name'] == team, corner_stats[team], games['home_total_corners'])
    games['away_total_corners'] = np.where(games['away_team_name'] == team, corner_stats[team], games['away_total_corners'])
    
#Function to put team stats into games dataframe

fill_stats('Fulham')
fill_stats('Blackburn Rovers')
fill_stats('West Bromwich Albion')
fill_stats('Queens Park Rangers')
fill_stats('AFC Bournemouth')
fill_stats('Middlesbrough')
fill_stats('Barnsley')
fill_stats('Millwall')
fill_stats('Sheffield United')
fill_stats('Reading')
fill_stats('Cardiff City')
fill_stats('Nottingham Forest')
fill_stats('Hull City')
fill_stats('Blackpool')
fill_stats('Luton Town')
fill_stats('Stoke City')
fill_stats('Swansea City')
fill_stats('Derby County')
fill_stats('Huddersfield Town')
fill_stats('Preston North End')
fill_stats('Coventry City')
fill_stats('Peterborough United')
fill_stats('Birmingham City')
fill_stats('Bristol City')

#Reading in stats

# Some more EDA

# %% [markdown]
# # Over/Under 2.5?

# %%
games['over/under'] = np.where(games['home_team_goal_count'] + games['away_team_goal_count'] > 2.5, 1, 0)
# Adding column 0 represents under 2.5, 1 represents over 2.5

# %%
games['over/under'].value_counts()
# Out:
# 1    38
# 0    34
# Name: over/under, dtype: int64

# %% [markdown]
# # xG Over/Under 2.5?

# %%
games['xg_over/under'] = np.where(games['team_a_xg'] + games['team_b_xg'] > 2.99, 1, 0)
# Adding column 0 represents under 2.5, 1 represents over 2.5
games['xg_over/under_1.99'] = np.where(games['team_a_xg'] + games['team_b_xg'] > 1.99, 1, 0)
# Adding column 0 represents under 1.5, 1 represents over 1.5

# %%
games['xg_over/under'].value_counts()
# Out:
# 0    37
# 1    23
# Name: xg_over/under, dtype: int64

# %%
games['xg_over/under_1.99'].value_counts()
# Out:
# 1    59
# 0     1
# Name: xg_over/under_1.99, dtype: int64

# %% [markdown]
# # First Week

# %%
games['over/under_1.5'] = np.where(games['home_team_goal_count'] + games['away_team_goal_count'] > 1.5, 1, 0)
# Adding column 0 represents under 1.5, 1 represents over 1.5

# %%
first_matchweek = games[0:12]

# %%
first_matchweek['over/under'].value_counts()
# Out:
# 0    7
# 1    5
# Name: over/under, dtype: int64

# %%
first_matchweek['over/under_1.5'].value_counts()
# Out:
# 1    9
# 0    3
# Name: over/under_1.5, dtype: int64

# %%
first_matchweek['xg_over/under'].value_counts()
# Out:
# 0    7
# 1    5
# Name: xg_over/under, dtype: int64

# %%
first_matchweek['xg_over/under_1.99'].value_counts()
# Out:
# 1    11
# 0     1
# Name: xg_over/under_1.99, dtype: int64

# %%
games['home_team_goal_count_half_time'].sum()
# Out:
# 7

# %%
games['away_team_goal_count_half_time'].sum()
# Out:
# 4
