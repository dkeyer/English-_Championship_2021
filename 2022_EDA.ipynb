# %% [markdown]
# # 2022 Championship EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, RidgeCV, Lasso, \
LassoCV, ElasticNet, ElasticNetCV
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.decomposition import PCA

# %%
team_stats = pd.read_csv('../footy_data/championship_teams_2022.csv')
games = pd.read_csv('../footy_data/championship_games_2022.csv')

# %%
games = games[0:36]
games
#Dropping playoff matches
# Out:
#      timestamp               date_GMT    status  attendance  \
# 0   1628275500   Aug 06 2021 - 6:45pm  complete         NaN
# 1   1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# 2   1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# 3   1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# 4   1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# 5   1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# 6   1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# 7   1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# 8   1628344800   Aug 07 2021 - 2:00pm  complete         NaN
# 9   1628362800   Aug 07 2021 - 7:00pm  complete         NaN
# 10  1628425800  Aug 08 2021 - 12:30pm  complete         NaN
# 11  1628436600   Aug 08 2021 - 3:30pm  complete         NaN
# 12  1628940600  Aug 14 2021 - 11:30am  complete         NaN
# 13  1628949600   Aug 14 2021 - 2:00pm  complete         NaN
# 14  1628949600   Aug 14 2021 - 2:00pm  complete         NaN
# 15  1628949600   Aug 14 2021 - 2:00pm  complete         NaN
# 16  1628949600   Aug 14 2021 - 2:00pm  complete         NaN
# 17  1628949600   Aug 14 2021 - 2:00pm  complete         NaN
# 18  1628949600   Aug 14 2021 - 2:00pm  complete         NaN
# 19  1628949600   Aug 14 2021 - 2:00pm  complete         NaN
# 20  1628949600   Aug 14 2021 - 2:00pm  complete         NaN
# 21  1628949600   Aug 14 2021 - 2:00pm  complete         NaN
# 22  1628949600   Aug 14 2021 - 2:00pm  complete         NaN
# 23  1628967600   Aug 14 2021 - 7:00pm  complete         NaN
# 24  1629225900   Aug 17 2021 - 6:45pm  complete         NaN
# 25  1629225900   Aug 17 2021 - 6:45pm  complete         NaN
# 26  1629225900   Aug 17 2021 - 6:45pm  complete         NaN
# 27  1629225900   Aug 17 2021 - 6:45pm  complete         NaN
# 28  1629225900   Aug 17 2021 - 6:45pm  complete         NaN
# 29  1629225900   Aug 17 2021 - 6:45pm  complete         NaN
# 30  1629226800   Aug 17 2021 - 7:00pm  complete         NaN
# 31  1629312300   Aug 18 2021 - 6:45pm  complete         NaN
# 32  1629312300   Aug 18 2021 - 6:45pm  complete         NaN
# 33  1629312300   Aug 18 2021 - 6:45pm  complete         NaN
# 34  1629312300   Aug 18 2021 - 6:45pm  complete         NaN
# 35  1629313200   Aug 18 2021 - 7:00pm  complete         NaN
#
#           home_team_name        away_team_name           referee  Game Week  \
# 0        AFC Bournemouth  West Bromwich Albion   Dean Whitestone          1
# 1       Blackburn Rovers          Swansea City        David Webb          1
# 2           Bristol City             Blackpool       Andy Davies          1
# 3           Cardiff City              Barnsley      Steve Martin          1
# 4           Derby County     Huddersfield Town  Geoff Eltringham          1
# 5             Luton Town   Peterborough United      Andy Woolmer          1
# 6      Preston North End             Hull City        Gavin Ward          1
# 7    Queens Park Rangers              Millwall   Oliver Langford          1
# 8             Stoke City               Reading      Matt Donohue          1
# 9       Sheffield United       Birmingham City      Tim Robinson          1
# 10                Fulham         Middlesbrough      Keith Stroud          1
# 11         Coventry City     Nottingham Forest   James Linington          1
# 12   Peterborough United          Derby County        David Webb          2
# 13              Barnsley         Coventry City        John Busby          2
# 14       Birmingham City            Stoke City        Gavin Ward          2
# 15             Blackpool          Cardiff City      Andy Woolmer          2
# 16     Huddersfield Town                Fulham   Dean Whitestone          2
# 17             Hull City   Queens Park Rangers      Matt Donohue          2
# 18         Middlesbrough          Bristol City   Oliver Langford          2
# 19              Millwall      Blackburn Rovers       Andy Davies          2
# 20     Nottingham Forest       AFC Bournemouth  Geoff Eltringham          2
# 21               Reading     Preston North End      Joshua Smith          2
# 22  West Bromwich Albion            Luton Town      Tim Robinson          2
# 23          Swansea City      Sheffield United      Keith Stroud          2
# 24              Barnsley            Luton Town   Oliver Langford          3
# 25             Blackpool         Coventry City      Keith Stroud          3
# 26     Huddersfield Town     Preston North End   James Linington          3
# 27              Millwall                Fulham  Geoff Eltringham          3
# 28   Peterborough United          Cardiff City    Thomas Bramall          3
# 29          Swansea City            Stoke City      Joshua Smith          3
# 30               Reading          Bristol City      Andy Woolmer          3
# 31       Birmingham City       AFC Bournemouth       Andy Davies          3
# 32             Hull City          Derby County   Dean Whitestone          3
# 33         Middlesbrough   Queens Park Rangers      Steve Martin          3
# 34     Nottingham Forest      Blackburn Rovers        Gavin Ward          3
# 35  West Bromwich Albion      Sheffield United      Matt Donohue          3
#
#     Pre-Match PPG (Home)  Pre-Match PPG (Away)  ...  odds_ft_home_team_win  \
# 0                    0.0                   0.0  ...                   2.30
# 1                    0.0                   0.0  ...                   2.20
# 2                    0.0                   0.0  ...                   2.20
# 3                    0.0                   0.0  ...                   2.50
# 4                    0.0                   0.0  ...                   2.60
# 5                    0.0                   0.0  ...                   2.60
# 6                    0.0                   0.0  ...                   2.35
# 7                    0.0                   0.0  ...                   2.15
# 8                    0.0                   0.0  ...                   2.10
# 9                    0.0                   0.0  ...                   1.80
# 10                   0.0                   0.0  ...                   1.83
# 11                   0.0                   0.0  ...                   2.25
# 12                   0.0                   0.0  ...                   2.50
# 13                   0.0                   0.0  ...                   2.10
# 14                   0.0                   0.0  ...                   2.80
# 15                   0.0                   0.0  ...                   2.90
# 16                   0.0                   0.0  ...                   4.45
# 17                   0.0                   0.0  ...                   2.50
# 18                   0.0                   0.0  ...                   1.91
# 19                   0.0                   0.0  ...                   2.20
# 20                   0.0                   0.0  ...                   3.15
# 21                   0.0                   0.0  ...                   2.25
# 22                   0.0                   0.0  ...                   1.71
# 23                   0.0                   0.0  ...                   3.20
# 24                   3.0                   0.0  ...                   2.29
# 25                   0.0                   0.0  ...                   2.75
# 26                   0.0                   0.0  ...                   2.59
# 27                   1.0                   3.0  ...                   3.30
# 28                   3.0                   3.0  ...                   2.87
# 29                   1.0                   1.0  ...                   2.95
# 30                   3.0                   0.0  ...                   2.23
# 31                   1.0                   3.0  ...                   2.65
# 32                   0.0                   0.0  ...                   2.00
# 33                   3.0                   3.0  ...                   2.50
# 34                   0.0                   1.0  ...                   2.50
# 35                   3.0                   1.0  ...                   2.00
#
#     odds_ft_draw  odds_ft_away_team_win  odds_ft_over15  odds_ft_over25  \
# 0           3.40                   3.10            1.33            1.85
# 1           3.25                   3.60            1.38            2.15
# 2           3.35                   3.45            1.39            2.10
# 3           3.20                   3.00            1.45            2.25
# 4           3.35                   2.80            1.43            2.15
# 5           3.35                   2.20            1.30            2.00
# 6           3.30                   3.20            1.39            2.10
# 7           3.35                   3.65            1.42            2.10
# 8           3.25                   3.90            1.53            2.45
# 9           3.40                   5.25            1.49            2.40
# 10          3.50                   4.75            1.43            2.15
# 11          3.15                   3.60            1.50            2.40
# 12          3.20                   3.05            1.44            2.25
# 13          3.25                   3.80            1.43            2.20
# 14          3.00                   2.85            1.50            2.45
# 15          3.15                   2.65            1.47            2.25
# 16          3.40                   1.91            1.44            2.25
# 17          3.20                   3.00            1.39            2.00
# 18          3.25                   4.75            1.50            2.40
# 19          3.15                   3.75            1.45            2.20
# 20          3.15                   2.45            1.44            2.20
# 21          3.25                   3.40            1.43            2.15
# 22          3.75                   5.25            1.30            1.83
# 23          3.25                   2.40            1.49            2.30
# 24          3.10                   3.10            1.36            2.05
# 25          2.97                   2.63            1.38            2.20
# 26          3.10                   2.70            1.38            2.10
# 27          2.95                   2.28            1.42            2.25
# 28          3.05                   2.46            1.38            2.20
# 29          3.10                   2.38            1.38            2.20
# 30          3.20                   3.10            1.36            2.05
# 31          3.10                   2.90            1.48            2.25
# 32          3.20                   4.25            1.49            2.30
# 33          3.20                   3.00            1.42            2.15
# 34          3.20                   3.00            1.43            2.15
# 35          3.30                   4.20            1.42            2.15
#
#     odds_ft_over35  odds_ft_over45  odds_btts_yes odds_btts_no  \
# 0             3.15            6.00           1.80         2.05
# 1             3.65            7.25           1.95         1.87
# 2             3.45            6.75           1.95         1.91
# 3             3.85            7.50           1.95         1.91
# 4             3.70            7.00           1.95         1.87
# 5             3.25            6.00           1.73         2.00
# 6             3.45            6.50           1.91         1.95
# 7             3.55            6.75           1.91         1.91
# 8             4.35            8.75           2.20         1.69
# 9             4.35            8.75           2.25         1.67
# 10            3.80            7.25           2.00         1.83
# 11            4.25            8.50           2.10         1.74
# 12            3.80            7.50           2.00         1.83
# 13            3.80            7.50           2.00         1.80
# 14            4.25            8.50           2.15         1.74
# 15            3.85            7.50           1.95         1.87
# 16            3.90            7.75           2.10         1.77
# 17            3.35            6.50           1.83         2.00
# 18            4.25            8.75           2.20         1.71
# 19            3.85            7.75           2.00         1.83
# 20            3.80            7.25           2.00         1.83
# 21            3.75            7.25           1.95         1.87
# 22            3.15            6.00           1.80         2.05
# 23            4.00            7.75           2.10         1.77
# 24            4.00            8.00           2.05         1.80
# 25            4.10            8.00           2.05         1.80
# 26            3.90            7.75           2.05         1.80
# 27            3.90            7.75           2.00         1.83
# 28            3.95            7.75           2.05         1.80
# 29            4.05            8.00           2.05         1.80
# 30            3.60            7.00           1.95         1.87
# 31            3.95            7.75           2.00         1.83
# 32            4.10            8.25           2.10         1.74
# 33            3.60            6.75           1.87         1.95
# 34            3.65            7.00           1.87         1.95
# 35            3.65            7.25           2.00         1.83
#
#                                          stadium_name
# 0              Vitality Stadium (Bournemouth- Dorset)
# 1                  Ewood Park (Blackburn- Lancashire)
# 2                               Ashton Gate (Bristol)
# 3           Cardiff City Stadium (Cardiff (Caerdydd))
# 4                          Pride Park Stadium (Derby)
# 5               Kenilworth Road (Luton- Bedfordshire)
# 6                                  Deepdale (Preston)
# 7            Kiyan Prince Foundation Stadium (London)
# 8      bet365 Stadium (Stoke-on-Trent- Staffordshire)
# 9                            Bramall Lane (Sheffield)
# 10                            Craven Cottage (London)
# 11  The Coventry Building Society Arena (Coventry-...
# 12                Weston Homes Stadium (Peterborough)
# 13                Oakwell (Barnsley- South Yorkshire)
# 14   St Andrew's Trillion Trophy Stadium (Birmingham)
# 15            Bloomfield Road (Blackpool- Lancashire)
# 16  John Smith's Stadium (Huddersfield- West Yorks...
# 17                             The MKM Stadium (Hull)
# 18                  Riverside Stadium (Middlesbrough)
# 19                                   The Den (London)
# 20      The City Ground (Nottingham- Nottinghamshire)
# 21    Select Car Leasing Stadium (Reading- Berkshire)
# 22                      The Hawthorns (West Bromwich)
# 23                      Swansea.com Stadium (Swansea)
# 24                Oakwell (Barnsley- South Yorkshire)
# 25            Bloomfield Road (Blackpool- Lancashire)
# 26  John Smith's Stadium (Huddersfield- West Yorks...
# 27                                   The Den (London)
# 28                Weston Homes Stadium (Peterborough)
# 29                      Swansea.com Stadium (Swansea)
# 30    Select Car Leasing Stadium (Reading- Berkshire)
# 31   St Andrew's Trillion Trophy Stadium (Birmingham)
# 32                             The MKM Stadium (Hull)
# 33                  Riverside Stadium (Middlesbrough)
# 34      The City Ground (Nottingham- Nottinghamshire)
# 35                      The Hawthorns (West Bromwich)
#
# [36 rows x 64 columns]

# %%
xg_view = games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view
# Out:
#           home_team_name        away_team_name  team_a_xg  team_b_xg  \
# 0        AFC Bournemouth  West Bromwich Albion       1.08       2.03
# 1       Blackburn Rovers          Swansea City       2.29       1.15
# 2           Bristol City             Blackpool       1.28       0.93
# 3           Cardiff City              Barnsley       1.52       1.23
# 4           Derby County     Huddersfield Town       1.27       1.85
# 5             Luton Town   Peterborough United       1.73       0.78
# 6      Preston North End             Hull City       1.01       1.87
# 7    Queens Park Rangers              Millwall       1.52       1.58
# 8             Stoke City               Reading       2.02       1.60
# 9       Sheffield United       Birmingham City       1.43       1.13
# 10                Fulham         Middlesbrough       1.81       1.02
# 11         Coventry City     Nottingham Forest       1.48       1.32
# 12   Peterborough United          Derby County       1.40       0.92
# 13              Barnsley         Coventry City       0.82       1.22
# 14       Birmingham City            Stoke City       1.19       1.04
# 15             Blackpool          Cardiff City       0.78       1.75
# 16     Huddersfield Town                Fulham       0.91       2.21
# 17             Hull City   Queens Park Rangers       1.10       1.78
# 18         Middlesbrough          Bristol City       1.47       1.05
# 19              Millwall      Blackburn Rovers       1.50       0.58
# 20     Nottingham Forest       AFC Bournemouth       1.93       1.08
# 21               Reading     Preston North End       1.41       1.18
# 22  West Bromwich Albion            Luton Town       2.12       1.29
# 23          Swansea City      Sheffield United       1.05       1.21
# 24              Barnsley            Luton Town       1.38       1.18
# 25             Blackpool         Coventry City       1.71       2.07
# 26     Huddersfield Town     Preston North End       1.04       1.18
# 27              Millwall                Fulham       1.04       2.10
# 28   Peterborough United          Cardiff City       1.03       1.21
# 29          Swansea City            Stoke City       1.14       1.45
# 30               Reading          Bristol City       1.47       1.24
# 31       Birmingham City       AFC Bournemouth       1.21       1.16
# 32             Hull City          Derby County       1.24       1.42
# 33         Middlesbrough   Queens Park Rangers       2.05       1.23
# 34     Nottingham Forest      Blackburn Rovers       1.19       1.37
# 35  West Bromwich Albion      Sheffield United       1.51       0.85
#
#     home_team_goal_count  away_team_goal_count
# 0                      2                     2
# 1                      2                     1
# 2                      1                     1
# 3                      1                     1
# 4                      1                     1
# 5                      3                     0
# 6                      1                     4
# 7                      1                     1
# 8                      3                     2
# 9                      0                     1
# 10                     1                     1
# 11                     2                     1
# 12                     2                     1
# 13                     1                     0
# 14                     0                     0
# 15                     0                     2
# 16                     1                     5
# 17                     0                     3
# 18                     2                     1
# 19                     1                     1
# 20                     1                     2
# 21                     2                     1
# 22                     3                     2
# 23                     0                     0
# 24                     0                     1
# 25                     0                     1
# 26                     1                     0
# 27                     1                     2
# 28                     2                     2
# 29                     1                     3
# 30                     2                     3
# 31                     0                     2
# 32                     0                     1
# 33                     2                     3
# 34                     1                     2
# 35                     4                     0

# %% [markdown]
# # Goal Analysis

# %%
season_goal_total = games['total_goal_count'].sum()
season_1h_goal_total = games['total_goals_at_half_time'].sum()
percent_goals_1h = ((season_1h_goal_total)/(season_goal_total)) * 100

# %%
print(f'There were {season_goal_total} goals scored this season')
# Out:
# There were 99 goals scored this season

# %%
print(f'There were {season_1h_goal_total} goals scored in the 1H this season, ')
# Out:
# There were 38 goals scored in the 1H this season,

# %%
round(season_1h_goal_total/season_goal_total, 2)
#% of first half goals
# Out:
# 0.38

# %%
games['total_goals_at_half_time'].count()
# Out:
# 36

# %%
games['total_goals_at_half_time'].value_counts()
# Out:
# 1    16
# 0    11
# 2     6
# 3     2
# 4     1
# Name: total_goals_at_half_time, dtype: int64

# %%
(191/557) * 100
#0-0 halftime
# Out:
# 34.29084380610413

# %%
# Out:
# 0.7127468581687613

# %% [markdown]
# # Adding more columns

# %%
games['home_xg'] = ""
games['away_xg'] = ""
games['home_xg_against'] = ""
games['away_xg_against'] = ""
games['home_total_corners'] = ""
games['away_total_corners'] = ""

# Creating new columns where our data will go

# %% [markdown]
# Let's write a function to help fill xg in our games df

# %%
xg_stats = team_stats[['common_name', 'xg_for_avg_overall']]
corner_stats = team_stats[['common_name', 'corners_per_match']]
xga_stats = team_stats[['common_name', 'xg_against_avg_overall']]

xga_stats.head()
# Out:
#             common_name  xg_against_avg_overall
# 0            Stoke City                    0.64
# 1  West Bromwich Albion                    0.41
# 2         Middlesbrough                    0.69
# 3       AFC Bournemouth                    1.06
# 4             Hull City                    0.74

# %%
xg_stats = dict(xg_stats.values)
corner_stats = dict(corner_stats.values)
xga_stats = dict(xga_stats.values)

#By making this into dictionaries, it will be easier to call them/update them with the function

# %%
def fill_stats(team):
    games['home_xg'] = np.where(games['home_team_name'] == team, xg_stats[team], games['home_xg'])
    games['away_xg'] = np.where(games['away_team_name'] == team, xg_stats[team], games['away_xg'])
    games['home_xg_against'] = np.where(games['home_team_name'] == team, xga_stats[team], games['home_xg_against'])
    games['away_xg_against'] = np.where(games['away_team_name'] == team, xga_stats[team], games['away_xg_against'])
    games['home_total_corners'] = np.where(games['home_team_name'] == team, corner_stats[team], games['home_total_corners'])
    games['away_total_corners'] = np.where(games['away_team_name'] == team, corner_stats[team], games['away_total_corners'])
    
#Function to put team stats into games dataframe

# %%
fill_stats('Fulham')
fill_stats('Blackburn Rovers')
fill_stats('West Bromwich Albion')
fill_stats('Queens Park Rangers')
fill_stats('AFC Bournemouth')
fill_stats('Middlesbrough')
fill_stats('Barnsley')
fill_stats('Millwall')
fill_stats('Sheffield United')
fill_stats('Reading')
fill_stats('Cardiff City')
fill_stats('Nottingham Forest')
fill_stats('Hull City')
fill_stats('Blackpool')
fill_stats('Luton Town')
fill_stats('Stoke City')
fill_stats('Swansea City')
fill_stats('Derby County')
fill_stats('Huddersfield Town')
fill_stats('Preston North End')
fill_stats('Coventry City')
fill_stats('Peterborough United')
fill_stats('Birmingham City')
fill_stats('Bristol City')

#Reading in stats

# %% [markdown]
# # Some more EDA

# %% [markdown]
# Let's write a function to help fill xg in our games df

# %%
games['home_xg'] = ""
games['away_xg'] = ""
games['home_xg_against'] = ""
games['away_xg_against'] = ""
games['home_total_corners'] = ""
games['away_total_corners'] = ""

# Creating new columns where our data will go



xg_stats = team_stats[['common_name', 'xg_for_avg_overall']]
corner_stats = team_stats[['common_name', 'corners_per_match']]
xga_stats = team_stats[['common_name', 'xg_against_avg_overall']]

xga_stats.head()

xg_stats = dict(xg_stats.values)
corner_stats = dict(corner_stats.values)
xga_stats = dict(xga_stats.values)

#By making this into dictionaries, it will be easier to call them/update them with the function

def fill_stats(team):
    games['home_xg'] = np.where(games['home_team_name'] == team, xg_stats[team], games['home_xg'])
    games['away_xg'] = np.where(games['away_team_name'] == team, xg_stats[team], games['away_xg'])
    games['home_xg_against'] = np.where(games['home_team_name'] == team, xga_stats[team], games['home_xg_against'])
    games['away_xg_against'] = np.where(games['away_team_name'] == team, xga_stats[team], games['away_xg_against'])
    games['home_total_corners'] = np.where(games['home_team_name'] == team, corner_stats[team], games['home_total_corners'])
    games['away_total_corners'] = np.where(games['away_team_name'] == team, corner_stats[team], games['away_total_corners'])
    
#Function to put team stats into games dataframe

fill_stats('Fulham')
fill_stats('Blackburn Rovers')
fill_stats('West Bromwich Albion')
fill_stats('Queens Park Rangers')
fill_stats('AFC Bournemouth')
fill_stats('Middlesbrough')
fill_stats('Barnsley')
fill_stats('Millwall')
fill_stats('Sheffield United')
fill_stats('Reading')
fill_stats('Cardiff City')
fill_stats('Nottingham Forest')
fill_stats('Hull City')
fill_stats('Blackpool')
fill_stats('Luton Town')
fill_stats('Stoke City')
fill_stats('Swansea City')
fill_stats('Derby County')
fill_stats('Huddersfield Town')
fill_stats('Preston North End')
fill_stats('Coventry City')
fill_stats('Peterborough United')
fill_stats('Birmingham City')
fill_stats('Bristol City')

#Reading in stats

# Some more EDA

# %% [markdown]
# # Over/Under 2.5?

# %%
games['over/under'] = np.where(games['home_team_goal_count'] + games['away_team_goal_count'] > 2.5, 1, 0)
# Adding column 0 represents under 2.5, 1 represents over 2.5

# %%
games['over/under'].value_counts()
# Out:
# 1    20
# 0    16
# Name: over/under, dtype: int64

# %% [markdown]
# # xG Over/Under 2.5?

# %%
games['xg_over/under'] = np.where(games['team_a_xg'] + games['team_b_xg'] > 2.5, 1, 0)
# Adding column 0 represents under 2.5, 1 represents over 2.5
games['xg_over/under_1.99'] = np.where(games['team_a_xg'] + games['team_b_xg'] > 1.99, 1, 0)
# Adding column 0 represents under 1.5, 1 represents over 1.5

# %%
games['xg_over/under'].value_counts()

# %%
games['xg_over/under_1.99'].value_counts()

# %%
369/552

# %% [markdown]
# # First Week

# %%
games['over/under_1.5'] = np.where(games['home_team_goal_count'] + games['away_team_goal_count'] > 1.5, 1, 0)
# Adding column 0 represents under 1.5, 1 represents over 1.5

# %%
first_matchweek = games[0:12]

# %%
first_matchweek['over/under'].value_counts()

# %%
first_matchweek['over/under_1.5'].value_counts()

# %%
first_matchweek['xg_over/under'].value_counts()

# %%
first_matchweek['xg_over/under_1.99'].value_counts()

# %% [markdown]
# # Let's take out the final week now and check percentage

# %%
first_41 = games[0:540]
first_41['over/under'].value_counts()

# %%
217/540
# Percentage of games that went over

# %% [markdown]
# # When were these goals scored?

# %% [markdown]
# Second half stoppage time goals will start at 91 i.e. 90+1 will be 91
# First half stoppage time goals will start at 100 i.e. 45+1 = 110 ----

# %%
goal_timings['All_goal_timings'].unique()

# %%
goal_timings['All_goal_timings'].value_counts()

# %% [markdown]
# Change stoppage time goals so we can cast them as floats

# %%
goal_timings = goal_timings.replace(to_replace="90'1", value = "91")
goal_timings = goal_timings.replace(to_replace="90'2", value = "92")
goal_timings = goal_timings.replace(to_replace="90'3", value = "93")
goal_timings = goal_timings.replace(to_replace="90'4", value = "94")
goal_timings = goal_timings.replace(to_replace="90'5", value = "95")
goal_timings = goal_timings.replace(to_replace="90'6", value = "96")
goal_timings = goal_timings.replace(to_replace="90'7", value = "97")
goal_timings = goal_timings.replace(to_replace="90'8", value = "98")
goal_timings = goal_timings.replace(to_replace="90'9", value = "99")
goal_timings = goal_timings.replace(to_replace="90'10", value = "100")
goal_timings = goal_timings.replace(to_replace="90'11", value = "101")
goal_timings = goal_timings.replace(to_replace="90'12", value = "102")
goal_timings = goal_timings.replace(to_replace="45'1", value = "110")
goal_timings = goal_timings.replace(to_replace="45'2", value = "111")
goal_timings = goal_timings.replace(to_replace="45'3", value = "112")
goal_timings = goal_timings.replace(to_replace="45'4", value = "113")

# %%
goal_timings['All_goal_timings'] = goal_timings['All_goal_timings'].astype('int')

# %%
timing_totals = goal_timings['All_goal_timings'].value_counts()
timing_totals = pd.DataFrame(timing_totals)

# %%
timing_totals = timing_totals.rename_axis("minute", axis="columns")
timing_totals = timing_totals.rename(columns={"All_goal_timings":"count"})

# %%
timing_totals['section'] = ""
timing_totals.head()

# %% [markdown]
# # In how many games did a team have more xG but lose?
