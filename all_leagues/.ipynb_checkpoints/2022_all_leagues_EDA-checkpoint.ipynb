# %% [markdown]
# # 2022 Championship EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
prem_team_stats = pd.read_csv('../../footy_data/england-premier-league-teams-2021-to-2022-stats.csv')
prem_games = pd.read_csv('../../footy_data/england-premier-league-matches-2021-to-2022-stats.csv')
champ_team_stats = pd.read_csv('../../footy_data/england-championship-teams-2021-to-2022-stats.csv')
champ_games = pd.read_csv('../../footy_data/england-championship-matches-2021-to-2022-stats.csv')
league_one_team_stats = pd.read_csv('../../footy_data/england-efl-league-one-teams-2021-to-2022-stats.csv')
league_one_games = pd.read_csv('../../footy_data/england-efl-league-one-matches-2021-to-2022-stats.csv')
league_two_team_stats = pd.read_csv('../../footy_data/england-efl-league-two-teams-2021-to-2022-stats.csv')
league_two_games = pd.read_csv('../../footy_data/england-efl-league-two-matches-2021-to-2022-stats.csv')
segunda_team_stats = pd.read_csv('../../footy_data/spain-segunda-division-teams-2021-to-2022-stats.csv')
segunda_games = pd.read_csv('../../footy_data/spain-segunda-division-matches-2021-to-2022-stats.csv')
laliga_teams_stats = pd.read_csv('../../footy_data/spain-la-liga-teams-2021-to-2022-stats.csv')
laliga_games = pd.read_csv('../../footy_data/spain-la-liga-matches-2021-to-2022-stats.csv')

# %%
prem_games = prem_games.loc[prem_games['status'] == 'complete']
champ_games = champ_games.loc[champ_games['status'] == 'complete']
league_one_games = league_one_games.loc[league_one_games['status'] == 'complete']
league_two_games = league_two_games.loc[league_two_games['status'] == 'complete']
segunda_games = segunda_games.loc[segunda_games['status'] == 'complete']
laliga_games = laliga_games.loc[laliga_games['status'] == 'complete']
#Played matches

# %% [markdown]
# # English Championship

# %%
champ_team_stats['real_xg'] = ""
champ_team_stats['real_xga'] = ""

# %% [markdown]
# The average xG stats for each team in Footystats' spreadsheet is incorrect, so I'll write a function to fill it myself

# %%
def xg_fixer(team_name):
    total = champ_games.loc[champ_games['home_team_name'] == team_name, 'team_a_xg'].sum()
    total = total + champ_games.loc[champ_games['away_team_name'] == team_name, 'team_b_xg'].sum()
    total = total / (champ_team_stats.loc[champ_team_stats['common_name'] == team_name, 'matches_played'].iloc[0])
    champ_team_stats['real_xg'] = np.where(champ_team_stats['common_name'] == team_name, total, champ_team_stats['real_xg'])

# %%
champ_team_stats['common_name'][0]
# Out:
# 'Stoke City'

# %%
xg_fixer(champ_team_stats['common_name'][0])
xg_fixer(champ_team_stats['common_name'][1])
xg_fixer(champ_team_stats['common_name'][2])
xg_fixer(champ_team_stats['common_name'][3])
xg_fixer(champ_team_stats['common_name'][4])
xg_fixer(champ_team_stats['common_name'][5])
xg_fixer(champ_team_stats['common_name'][6])
xg_fixer(champ_team_stats['common_name'][7])
xg_fixer(champ_team_stats['common_name'][8])
xg_fixer(champ_team_stats['common_name'][9])
xg_fixer(champ_team_stats['common_name'][10])
xg_fixer(champ_team_stats['common_name'][11])
xg_fixer(champ_team_stats['common_name'][12])
xg_fixer(champ_team_stats['common_name'][13])
xg_fixer(champ_team_stats['common_name'][14])
xg_fixer(champ_team_stats['common_name'][15])
xg_fixer(champ_team_stats['common_name'][16])
xg_fixer(champ_team_stats['common_name'][17])
xg_fixer(champ_team_stats['common_name'][18])
xg_fixer(champ_team_stats['common_name'][19])
xg_fixer(champ_team_stats['common_name'][20])
xg_fixer(champ_team_stats['common_name'][21])
xg_fixer(champ_team_stats['common_name'][22])
xg_fixer(champ_team_stats['common_name'][23])
#Lambda

# %%
#XGA_FIXER function here

# %%
champ_team_stats.head()
# Out:
#                  team_name           common_name     season  country  \
# 0            Stoke City FC            Stoke City  2021/2022  England
# 1  West Bromwich Albion FC  West Bromwich Albion  2021/2022  England
# 2         Middlesbrough FC         Middlesbrough  2021/2022  England
# 3          AFC Bournemouth       AFC Bournemouth  2021/2022  England
# 4            Hull City AFC             Hull City  2021/2022  England
#
#    matches_played  matches_played_home  matches_played_away  \
# 0              17                    8                    9
# 1              17                    9                    8
# 2              17                    8                    9
# 3              17                    9                    8
# 4              17                    8                    9
#
#    suspended_matches  wins  wins_home  ...  goals_conceded_min_81_to_90  \
# 0                  0     8          5  ...                            1
# 1                  0     9          6  ...                            3
# 2                  0     6          4  ...                            3
# 3                  0    12          6  ...                            0
# 4                  0     3          1  ...                            0
#
#    draw_percentage_overall  draw_percentage_home  draw_percentage_away  \
# 0                       24                    25                    22
# 1                       29                    33                    25
# 2                       24                    13                    33
# 3                       24                    22                    25
# 4                       18                    25                    11
#
#    loss_percentage_ovearll  loss_percentage_home  loss_percentage_away  \
# 0                       29                    13                    44
# 1                       18                     0                    38
# 2                       41                    38                    44
# 3                        6                    11                     0
# 4                       65                    63                    67
#
#    over145_corners_percentage  real_xg  real_xga
# 0                          24  1.46765
# 1                           6  1.83235
# 2                          12  1.56471
# 3                          12  1.49882
# 4                           0  1.36294
#
# [5 rows x 295 columns]

# %%
xg_view = champ_games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[(len(champ_games) - 50):len(champ_games)]
#We just want to see the most recent games here
# Out:
#            home_team_name        away_team_name  team_a_xg  team_b_xg  \
# 154          Swansea City  West Bromwich Albion       1.15       1.32
# 155               Reading             Blackpool       0.97       2.54
# 156          Cardiff City         Middlesbrough       1.07       2.47
# 157       AFC Bournemouth     Huddersfield Town       1.90       0.67
# 158       Birmingham City          Swansea City       1.58       1.02
# 159      Blackburn Rovers               Reading       1.46       1.60
# 160             Blackpool     Preston North End       1.37       1.20
# 161         Coventry City          Derby County       1.32       1.01
# 162            Luton Town             Hull City       1.67       1.37
# 163              Millwall            Stoke City       1.21       1.51
# 164   Peterborough United   Queens Park Rangers       1.84       1.97
# 165  West Bromwich Albion          Bristol City       2.71       1.01
# 166              Barnsley      Sheffield United       1.46       1.49
# 167     Nottingham Forest                Fulham       1.10       1.38
# 168   Queens Park Rangers     Nottingham Forest       1.57       1.61
# 169                Fulham  West Bromwich Albion       1.56       1.52
# 170          Bristol City              Barnsley       1.18       2.11
# 171          Derby County      Blackburn Rovers       1.05       1.29
# 172     Huddersfield Town              Millwall       1.85       0.77
# 173             Hull City         Coventry City       1.51       1.24
# 174         Middlesbrough       Birmingham City       1.48       1.14
# 175     Preston North End            Luton Town       1.61       1.35
# 176      Sheffield United             Blackpool       1.76       0.72
# 177            Stoke City          Cardiff City       1.63       1.19
# 178          Swansea City   Peterborough United       1.64       0.38
# 179               Reading       AFC Bournemouth       1.24       1.20
# 180       Birmingham City          Bristol City       1.53       1.22
# 181         Coventry City          Swansea City       1.43       1.23
# 182            Luton Town         Middlesbrough       1.31       1.31
# 183              Millwall               Reading       1.99       0.83
# 184     Nottingham Forest      Sheffield United       1.17       1.09
# 185   Peterborough United     Huddersfield Town       1.43       1.29
# 186       AFC Bournemouth     Preston North End       1.66       1.04
# 187              Barnsley          Derby County       1.00       1.50
# 188      Blackburn Rovers                Fulham       0.67       2.21
# 189             Blackpool            Stoke City       0.80       1.25
# 190          Cardiff City   Queens Park Rangers       1.01       1.00
# 191  West Bromwich Albion             Hull City       1.74       0.59
# 192       AFC Bournemouth          Swansea City       1.84       0.96
# 193              Barnsley             Hull City       1.79       2.00
# 194      Blackburn Rovers      Sheffield United       1.68       1.39
# 195          Cardiff City     Huddersfield Town       1.85       1.19
# 196         Coventry City          Bristol City       1.90       0.91
# 197            Luton Town            Stoke City       0.97       0.88
# 198              Millwall          Derby County       1.53       1.53
# 199     Nottingham Forest     Preston North End       1.34       0.93
# 200   Peterborough United                Fulham       1.29       1.51
# 201  West Bromwich Albion         Middlesbrough       1.34       0.96
# 202       Birmingham City               Reading       1.59       1.27
# 203             Blackpool   Queens Park Rangers       1.39       0.71
#
#      home_team_goal_count  away_team_goal_count
# 154                     2                     1
# 155                     2                     3
# 156                     0                     2
# 157                     3                     0
# 158                     2                     1
# 159                     2                     0
# 160                     2                     0
# 161                     1                     1
# 162                     1                     0
# 163                     2                     1
# 164                     2                     1
# 165                     3                     0
# 166                     2                     3
# 167                     0                     4
# 168                     1                     1
# 169                     3                     0
# 170                     2                     1
# 171                     1                     2
# 172                     1                     0
# 173                     0                     1
# 174                     0                     2
# 175                     2                     0
# 176                     0                     1
# 177                     3                     3
# 178                     3                     0
# 179                     0                     2
# 180                     3                     0
# 181                     1                     2
# 182                     3                     1
# 183                     1                     0
# 184                     1                     1
# 185                     1                     1
# 186                     1                     2
# 187                     2                     1
# 188                     0                     7
# 189                     0                     1
# 190                     0                     1
# 191                     1                     0
# 192                     4                     0
# 193                     0                     2
# 194                     3                     1
# 195                     2                     1
# 196                     3                     2
# 197                     0                     1
# 198                     1                     1
# 199                     3                     0
# 200                     0                     1
# 201                     1                     1
# 202                     1                     2
# 203                     1                     1

# %% [markdown]
# # Goal Analysis

# %%
season_goal_total = champ_games['total_goal_count'].sum()
season_1h_goal_total = champ_games['total_goals_at_half_time'].sum()
percent_goals_1h = ((season_1h_goal_total)/(season_goal_total)) * 100

# %%
print(f'There were {season_goal_total} goals scored this season')
# Out:
# There were 519 goals scored this season

# %%
print(f'There were {season_1h_goal_total} goals scored in the 1H this season, ')
# Out:
# There were 208 goals scored in the 1H this season,

# %%
round(season_1h_goal_total/season_goal_total, 2)
#% of first half goals
# Out:
# 0.4

# %%
champ_games['total_goals_at_half_time'].value_counts()
# Out:
# 1    76
# 0    70
# 2    46
# 3     8
# 4     4
# Name: total_goals_at_half_time, dtype: int64

# %% [markdown]
# More Columns

# %%
champ_games['home_xg'] = ""
champ_games['away_xg'] = ""
champ_games['home_xg_against'] = ""
champ_games['away_xg_against'] = ""
champ_games['home_total_corners'] = ""
champ_games['away_total_corners'] = ""

# Creating new columns where our data will go

# %% [markdown]
# Let's write a function to help fill xg in our games df

# %%
xg_stats = champ_team_stats[['common_name', 'xg_for_avg_overall']]
corner_stats = champ_team_stats[['common_name', 'corners_per_match']]
xga_stats = champ_team_stats[['common_name', 'xg_against_avg_overall']]
#creating new variables for the average stats -- eventually will go into the champ_games df

# %%
xg_stats = dict(xg_stats.values)
corner_stats = dict(corner_stats.values)
xga_stats = dict(xga_stats.values)

#By making this into dictionaries, it will be easier to call them/update them with the function

# %%
def fill_stats(team, games):
    games['home_xg'] = np.where(games['home_team_name'] == team, xg_stats[team], games['home_xg'])
    games['away_xg'] = np.where(games['away_team_name'] == team, xg_stats[team], games['away_xg'])
    games['home_xg_against'] = np.where(games['home_team_name'] == team, xga_stats[team], games['home_xg_against'])
    games['away_xg_against'] = np.where(games['away_team_name'] == team, xga_stats[team], games['away_xg_against'])
    games['home_total_corners'] = np.where(games['home_team_name'] == team, corner_stats[team], games['home_total_corners'])
    games['away_total_corners'] = np.where(games['away_team_name'] == team, corner_stats[team], games['away_total_corners'])
    
#Function to put team stats into games dataframe

# %%
fill_stats(champ_team_stats['common_name'][0], champ_games)
fill_stats(champ_team_stats['common_name'][1], champ_games)
fill_stats(champ_team_stats['common_name'][2], champ_games)
fill_stats(champ_team_stats['common_name'][4], champ_games)
fill_stats(champ_team_stats['common_name'][5], champ_games)
fill_stats(champ_team_stats['common_name'][6], champ_games)
fill_stats(champ_team_stats['common_name'][7], champ_games)
fill_stats(champ_team_stats['common_name'][8], champ_games)
fill_stats(champ_team_stats['common_name'][9], champ_games)
fill_stats(champ_team_stats['common_name'][10], champ_games)
fill_stats(champ_team_stats['common_name'][11], champ_games)
fill_stats(champ_team_stats['common_name'][12], champ_games)
fill_stats(champ_team_stats['common_name'][13], champ_games)
fill_stats(champ_team_stats['common_name'][14], champ_games)
fill_stats(champ_team_stats['common_name'][15], champ_games)
fill_stats(champ_team_stats['common_name'][16], champ_games)
fill_stats(champ_team_stats['common_name'][17], champ_games)
fill_stats(champ_team_stats['common_name'][18], champ_games)
fill_stats(champ_team_stats['common_name'][19], champ_games)
fill_stats(champ_team_stats['common_name'][20], champ_games)
fill_stats(champ_team_stats['common_name'][21], champ_games)
fill_stats(champ_team_stats['common_name'][22], champ_games)
fill_stats(champ_team_stats['common_name'][23], champ_games)

# %% [markdown]
# # Over/Under 2.5?

# %%
champ_games['over/under'] = np.where(champ_games['home_team_goal_count'] + champ_games['away_team_goal_count'] > 2.5, 1, 0)
# Adding column 0 represents under 2.5, 1 represents over 2.5

# %%
champ_games['over/under'].value_counts()
# Out:
# 0    103
# 1    101
# Name: over/under, dtype: int64

# %% [markdown]
# # League One

# %%
xg_view = league_one_games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[(len(league_one_games) - 50):len(league_one_games)]
# Out:
#           home_team_name       away_team_name  team_a_xg  team_b_xg  \
# 140           Gillingham           Sunderland       2.72       1.61
# 141         Lincoln City    Charlton Athletic       2.17       0.67
# 142        Oxford United      Plymouth Argyle       1.41       1.56
# 143     Rotherham United           Portsmouth       1.72       1.00
# 144      Shrewsbury Town   Milton Keynes Dons       0.76       1.52
# 145     Cambridge United  Sheffield Wednesday       1.54       2.38
# 146    Charlton Athletic   Accrington Stanley       1.95       2.05
# 147      Cheltenham Town            Morecambe       1.81       1.04
# 148      Crewe Alexandra           Sunderland       1.48       1.64
# 149       Fleetwood Town        Burton Albion       1.34       1.80
# 150           Gillingham     Doncaster Rovers       1.25       1.42
# 151         Lincoln City        AFC Wimbledon       1.80       1.17
# 152        Oxford United      Shrewsbury Town       1.80       1.03
# 153      Plymouth Argyle     Bolton Wanderers       2.29       1.59
# 154           Portsmouth         Ipswich Town       1.12       1.20
# 155     Rotherham United    Wycombe Wanderers       1.43       1.05
# 156       Wigan Athletic   Milton Keynes Dons       1.53       1.67
# 157        AFC Wimbledon       Wigan Athletic       1.02       1.90
# 158   Accrington Stanley           Portsmouth       1.28       2.22
# 159     Bolton Wanderers           Gillingham       2.83       1.86
# 160        Burton Albion        Oxford United       1.14       2.77
# 161     Doncaster Rovers      Cheltenham Town       1.57       2.04
# 162         Ipswich Town       Fleetwood Town       1.80       1.01
# 163   Milton Keynes Dons     Rotherham United       1.37       1.60
# 164            Morecambe      Plymouth Argyle       1.45       1.82
# 165  Sheffield Wednesday         Lincoln City       1.43       1.08
# 166      Shrewsbury Town     Cambridge United       2.09       0.89
# 167           Sunderland    Charlton Athletic       2.16       1.47
# 168    Wycombe Wanderers      Crewe Alexandra       2.30       1.43
# 169     Doncaster Rovers     Cambridge United       1.62       1.17
# 170       Wigan Athletic         Lincoln City       2.09       1.38
# 171     Cambridge United        AFC Wimbledon       1.35       1.18
# 172    Charlton Athletic     Doncaster Rovers       2.16       0.39
# 173      Cheltenham Town  Sheffield Wednesday       1.60       1.75
# 174      Crewe Alexandra   Milton Keynes Dons       0.93       1.53
# 175       Fleetwood Town    Wycombe Wanderers       1.83       2.27
# 176           Gillingham   Accrington Stanley       2.27       1.41
# 177         Lincoln City      Shrewsbury Town       1.67       2.15
# 178        Oxford United            Morecambe       1.58       2.04
# 179      Plymouth Argyle         Ipswich Town       1.60       1.21
# 180           Portsmouth     Bolton Wanderers       1.29       0.88
# 181     Rotherham United           Sunderland       2.57       0.99
# 182       Wigan Athletic        Burton Albion       2.66       0.49
# 183       Fleetwood Town       Wigan Athletic       1.06       2.15
# 184  Sheffield Wednesday           Sunderland       1.25       1.66
# 185    Wycombe Wanderers         Ipswich Town       2.41       1.71
# 186    Charlton Athletic     Rotherham United       1.60       1.58
# 187      Crewe Alexandra     Doncaster Rovers       0.89       1.66
# 188            Morecambe     Cambridge United       1.28       1.68
# 189           Portsmouth      Cheltenham Town       2.04       1.29
#
#      home_team_goal_count  away_team_goal_count
# 140                     1                     2
# 141                     2                     1
# 142                     1                     3
# 143                     4                     1
# 144                     1                     0
# 145                     1                     1
# 146                     2                     3
# 147                     3                     1
# 148                     0                     4
# 149                     0                     1
# 150                     1                     0
# 151                     0                     1
# 152                     2                     0
# 153                     3                     0
# 154                     0                     4
# 155                     0                     0
# 156                     1                     2
# 157                     0                     2
# 158                     2                     2
# 159                     2                     2
# 160                     1                     3
# 161                     3                     2
# 162                     2                     1
# 163                     0                     3
# 164                     1                     1
# 165                     1                     1
# 166                     4                     1
# 167                     0                     1
# 168                     2                     1
# 169                     1                     1
# 170                     1                     2
# 171                     1                     0
# 172                     4                     0
# 173                     2                     2
# 174                     1                     4
# 175                     3                     3
# 176                     0                     0
# 177                     1                     1
# 178                     3                     1
# 179                     2                     1
# 180                     1                     0
# 181                     5                     1
# 182                     2                     0
# 183                     2                     3
# 184                     3                     0
# 185                     1                     4
# 186                     1                     1
# 187                     1                     1
# 188                     0                     2
# 189                     1                     1

# %% [markdown]
# # League Two

# %%
xg_view = league_two_games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[(len(league_two_games) - 50):len(league_two_games)]
# Out:
#           home_team_name       away_team_name  team_a_xg  team_b_xg  \
# 130              Walsall         Salford City       1.92       1.09
# 131        Bradford City       Bristol Rovers       1.95       1.19
# 132      Carlisle United      Tranmere Rovers       1.82       1.49
# 133    Colchester United       Harrogate Town       1.13       1.67
# 134         Crawley Town        Sutton United       1.19       1.82
# 135          Exeter City       Newport County       1.73       1.60
# 136        Leyton Orient              Walsall       0.74       0.93
# 137     Northampton Town       Mansfield Town       1.14       0.97
# 138      Oldham Athletic            Stevenage       1.11       1.77
# 139            Port Vale               Barrow       1.43       1.10
# 140         Salford City    Hartlepool United       1.66       0.79
# 141    Scunthorpe United  Forest Green Rovers       1.02       1.45
# 142         Swindon Town             Rochdale       2.14       1.18
# 143               Barrow    Scunthorpe United       2.29       1.21
# 144        Bradford City    Hartlepool United       1.61       1.29
# 145    Colchester United       Bristol Rovers       1.75       1.32
# 146         Crawley Town          Exeter City       1.13       1.60
# 147       Harrogate Town      Tranmere Rovers       1.47       1.63
# 148        Leyton Orient  Forest Green Rovers       1.35       0.97
# 149       Mansfield Town            Port Vale       2.34       0.80
# 150       Newport County      Carlisle United       1.61       2.29
# 151     Northampton Town            Stevenage       1.11       0.81
# 152      Oldham Athletic              Walsall       1.30       1.74
# 153         Salford City             Rochdale       2.15       1.42
# 154        Sutton United         Swindon Town       1.06       1.82
# 155       Bristol Rovers       Newport County       1.51       1.71
# 156      Carlisle United      Oldham Athletic       1.10       1.63
# 157          Exeter City       Mansfield Town       1.95       0.90
# 158  Forest Green Rovers         Salford City       2.11       1.51
# 159    Hartlepool United       Harrogate Town       1.52       1.33
# 160            Port Vale    Colchester United       2.22       1.50
# 161             Rochdale        Sutton United       2.70       1.32
# 162    Scunthorpe United         Crawley Town       1.67       1.46
# 163            Stevenage        Leyton Orient       1.48       1.81
# 164         Swindon Town        Bradford City       1.43       1.39
# 165      Tranmere Rovers     Northampton Town       1.00       1.97
# 166              Walsall               Barrow       1.87       1.40
# 167    Colchester United        Sutton United       1.00       1.72
# 168     Northampton Town      Carlisle United       1.34       0.97
# 169        Bradford City  Forest Green Rovers       1.50       1.20
# 170    Colchester United    Scunthorpe United       1.10       1.30
# 171         Crawley Town            Port Vale       1.01       2.58
# 172       Harrogate Town       Bristol Rovers       1.35       0.89
# 173        Leyton Orient    Hartlepool United       1.85       0.69
# 174       Mansfield Town      Tranmere Rovers       1.28       1.22
# 175       Newport County            Stevenage       2.69       1.12
# 176      Oldham Athletic         Swindon Town       1.33       2.03
# 177         Salford City          Exeter City       1.40       1.66
# 178        Sutton United              Walsall       1.32       1.01
# 179               Barrow             Rochdale       1.41       1.49
#
#      home_team_goal_count  away_team_goal_count
# 130                     2                     1
# 131                     2                     2
# 132                     0                     1
# 133                     1                     0
# 134                     0                     1
# 135                     2                     2
# 136                     0                     0
# 137                     2                     0
# 138                     3                     0
# 139                     3                     1
# 140                     2                     0
# 141                     0                     2
# 142                     2                     2
# 143                     1                     1
# 144                     1                     3
# 145                     1                     1
# 146                     1                     3
# 147                     2                     2
# 148                     1                     1
# 149                     1                     1
# 150                     2                     2
# 151                     3                     0
# 152                     1                     3
# 153                     0                     0
# 154                     1                     2
# 155                     1                     3
# 156                     0                     0
# 157                     2                     1
# 158                     3                     1
# 159                     3                     2
# 160                     3                     0
# 161                     3                     2
# 162                     2                     1
# 163                     0                     0
# 164                     1                     3
# 165                     0                     2
# 166                     2                     2
# 167                     1                     3
# 168                     3                     0
# 169                     1                     1
# 170                     2                     1
# 171                     1                     4
# 172                     0                     1
# 173                     5                     0
# 174                     2                     0
# 175                     5                     0
# 176                     1                     3
# 177                     1                     2
# 178                     0                     1
# 179                     1                     2

# %% [markdown]
# # La Liga

# %%
xg_view = laliga_games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[(len(laliga_games) - 50):len(laliga_games)]
# Out:
#            home_team_name        away_team_name  team_a_xg  team_b_xg  \
# 78             Villarreal            Real Betis       1.53       1.29
# 79             Granada CF            Sevilla FC       0.92       1.77
# 80             Levante UD             Getafe CF       0.96       1.23
# 81          Real Sociedad          RCD Mallorca       1.27       1.01
# 84         Rayo Vallecano              Elche CF       1.61       1.03
# 85          Celta de Vigo            Sevilla FC       1.64       0.89
# 86             Villarreal            CA Osasuna       1.89       0.89
# 87           FC Barcelona           Valencia CF       1.68       1.21
# 88       Deportivo Alavés            Real Betis       1.48       2.01
# 89           RCD Espanyol                 Cádiz       1.73       1.49
# 90             CA Osasuna            Granada CF       1.90       1.21
# 91            Valencia CF          RCD Mallorca       2.44       1.27
# 92                  Cádiz      Deportivo Alavés       2.37       1.12
# 93               Elche CF          RCD Espanyol       2.05       2.18
# 94   Athletic Club Bilbao            Villarreal       2.00       1.36
# 95             Sevilla FC            Levante UD       2.25       1.53
# 96           FC Barcelona           Real Madrid       1.58       1.52
# 97             Real Betis        Rayo Vallecano       1.59       1.42
# 98        Atlético Madrid         Real Sociedad       2.06       1.08
# 99              Getafe CF         Celta de Vigo       1.19       2.04
# 100      Deportivo Alavés              Elche CF       1.67       0.97
# 101          RCD Espanyol  Athletic Club Bilbao       1.62       2.46
# 102            Villarreal                 Cádiz       2.33       1.30
# 103          RCD Mallorca            Sevilla FC       1.49       1.30
# 104        Rayo Vallecano          FC Barcelona       1.45       1.85
# 105            Real Betis           Valencia CF       1.87       1.31
# 106           Real Madrid            CA Osasuna       2.67       0.73
# 107         Celta de Vigo         Real Sociedad       1.77       1.33
# 108            Granada CF             Getafe CF       2.13       0.87
# 109            Levante UD       Atlético Madrid       1.29       1.09
# 110              Elche CF           Real Madrid       1.69       1.95
# 111            Sevilla FC            CA Osasuna       1.92       1.29
# 112           Valencia CF            Villarreal       1.10       1.52
# 113          FC Barcelona      Deportivo Alavés       2.27       0.55
# 114                 Cádiz          RCD Mallorca       1.44       1.39
# 115       Atlético Madrid            Real Betis       2.45       0.97
# 116             Getafe CF          RCD Espanyol       1.35       1.31
# 117         Real Sociedad  Athletic Club Bilbao       1.09       1.69
# 118        Rayo Vallecano         Celta de Vigo       1.56       1.30
# 119            Levante UD            Granada CF       1.57       1.42
# 120  Athletic Club Bilbao                 Cádiz       1.75       0.99
# 121          RCD Espanyol            Granada CF       2.12       1.98
# 122         Celta de Vigo          FC Barcelona       2.04       1.32
# 123      Deportivo Alavés            Levante UD       1.46       1.65
# 124           Real Madrid        Rayo Vallecano       1.96       2.14
# 125            Villarreal             Getafe CF       1.66       0.85
# 126           Valencia CF       Atlético Madrid       1.62       1.78
# 127          RCD Mallorca              Elche CF       2.30       0.92
# 128            CA Osasuna         Real Sociedad       1.07       1.23
# 129            Real Betis            Sevilla FC       0.98       1.70
#
#      home_team_goal_count  away_team_goal_count
# 78                      2                     0
# 79                      1                     0
# 80                      0                     0
# 81                      1                     0
# 84                      2                     1
# 85                      0                     1
# 86                      1                     2
# 87                      3                     1
# 88                      0                     1
# 89                      2                     0
# 90                      1                     1
# 91                      2                     2
# 92                      0                     2
# 93                      2                     2
# 94                      2                     1
# 95                      5                     3
# 96                      1                     2
# 97                      3                     2
# 98                      2                     2
# 99                      0                     3
# 100                     1                     0
# 101                     1                     1
# 102                     3                     3
# 103                     1                     1
# 104                     1                     0
# 105                     4                     1
# 106                     0                     0
# 107                     0                     2
# 108                     1                     1
# 109                     2                     2
# 110                     1                     2
# 111                     2                     0
# 112                     2                     0
# 113                     1                     1
# 114                     1                     1
# 115                     3                     0
# 116                     2                     1
# 117                     1                     1
# 118                     0                     0
# 119                     0                     3
# 120                     0                     1
# 121                     2                     0
# 122                     3                     3
# 123                     2                     1
# 124                     2                     1
# 125                     1                     0
# 126                     3                     3
# 127                     2                     2
# 128                     0                     2
# 129                     0                     2

# %% [markdown]
# # Segunda

# %%
xg_view = segunda_games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[(len(segunda_games) - 50):len(segunda_games)]
# Out:
#        home_team_name    away_team_name  team_a_xg  team_b_xg  \
# 115       AD Alcorcón           Leganés       1.19       2.66
# 116           CD Lugo     UD Las Palmas       0.87       1.59
# 117           Almería  Real Sociedad II       1.70       1.13
# 118     Real Zaragoza   SD Ponferradina       1.56       1.01
# 119          Mirandés         Girona FC       2.20       1.54
# 120       Real Oviedo         Burgos CF       1.81       0.99
# 121          SD Eibar      FC Cartagena       1.71       1.37
# 122          UD Ibiza    CF Fuenlabrada       1.20       1.39
# 123    Sporting Gijón   Real Valladolid       2.27       1.27
# 124         Málaga CF           CD Lugo       2.03       1.01
# 125           Leganés       CD Tenerife       1.45       0.91
# 126          Mirandés           Almería       1.61       1.53
# 127     SD Amorebieta  Real Sociedad II       1.67       1.41
# 128   SD Ponferradina       Real Oviedo       2.09       1.29
# 129         Burgos CF         SD Huesca       1.51       1.30
# 130     UD Las Palmas       AD Alcorcón       2.77       0.57
# 131         Girona FC     Real Zaragoza       1.80       1.47
# 132  Real Sociedad II     UD Las Palmas       1.16       0.99
# 133           Almería           Leganés       0.95       2.11
# 134         SD Huesca     SD Amorebieta       1.37       1.43
# 135           CD Lugo    Sporting Gijón       1.70       2.20
# 136      FC Cartagena   SD Ponferradina       1.55       1.45
# 137    CF Fuenlabrada         Girona FC       1.69       1.39
# 138       Real Oviedo         Málaga CF       2.27       1.13
# 139   Real Valladolid          SD Eibar       1.45       1.49
# 140     Real Zaragoza          Mirandés       1.09       2.13
# 141       AD Alcorcón          UD Ibiza       1.04       1.26
# 142       CD Tenerife         Burgos CF       2.13       1.23
# 143   SD Ponferradina         SD Huesca       2.24       0.99
# 144    Sporting Gijón           Almería       1.31       2.06
# 145           Leganés      FC Cartagena       1.82       0.86
# 146          Mirandés           CD Lugo       1.80       1.34
# 147     SD Amorebieta   Real Valladolid       1.21       1.45
# 148     UD Las Palmas    CF Fuenlabrada       1.78       0.96
# 149          SD Eibar       Real Oviedo       1.12       1.17
# 150         Burgos CF     Real Zaragoza       1.38       0.70
# 151         Girona FC       AD Alcorcón       1.51       1.43
# 152         Málaga CF  Real Sociedad II       1.13       1.23
# 153          UD Ibiza       CD Tenerife       1.08       1.03
# 154         SD Huesca           Leganés       1.17       0.87
# 155           CD Lugo   SD Ponferradina       1.29       2.06
# 156       Real Oviedo     UD Las Palmas       1.29       1.59
# 157   Real Valladolid          Mirandés       2.23       1.60
# 158    CF Fuenlabrada          SD Eibar       1.42       1.39
# 159       AD Alcorcón     SD Amorebieta       1.44       0.81
# 160     Real Zaragoza    Sporting Gijón       1.60       1.55
# 161           Almería         Burgos CF       1.97       1.15
# 162      FC Cartagena         Málaga CF       1.54       1.25
# 163  Real Sociedad II          UD Ibiza       0.81       1.37
# 164       CD Tenerife         Girona FC       1.43       1.34
#
#      home_team_goal_count  away_team_goal_count
# 115                     3                     3
# 116                     2                     0
# 117                     3                     1
# 118                     1                     1
# 119                     1                     2
# 120                     1                     3
# 121                     2                     1
# 122                     3                     1
# 123                     1                     2
# 124                     1                     0
# 125                     1                     2
# 126                     1                     4
# 127                     1                     2
# 128                     1                     2
# 129                     3                     1
# 130                     3                     0
# 131                     1                     1
# 132                     0                     1
# 133                     1                     0
# 134                     1                     1
# 135                     1                     1
# 136                     0                     1
# 137                     1                     2
# 138                     2                     1
# 139                     2                     0
# 140                     1                     1
# 141                     0                     2
# 142                     4                     0
# 143                     1                     1
# 144                     0                     1
# 145                     1                     1
# 146                     3                     2
# 147                     4                     1
# 148                     2                     1
# 149                     1                     0
# 150                     0                     1
# 151                     3                     1
# 152                     2                     1
# 153                     0                     0
# 154                     0                     2
# 155                     1                     2
# 156                     1                     1
# 157                     3                     1
# 158                     0                     0
# 159                     2                     2
# 160                     2                     0
# 161                     2                     0
# 162                     3                     1
# 163                     0                     1
# 164                     2                     1

# %% [markdown]
# # For Later

# %%
# league[['goals_min_0_to_10', 'goals_min_11_to_20', 'goals_min_21_to_30',
#        'goals_min_31_to_40', 'goals_min_41_to_50', 'goals_min_51_to_60',
#        'goals_min_61_to_70', 'goals_min_71_to_80', 'goals_min_81_to_90',
#        'goals_min_0_to_15', 'goals_min_16_to_30', 'goals_min_31_to_45',
#        'goals_min_46_to_60', 'goals_min_61_to_75', 'goals_min_76_to_90',
#        'xg_avg_per_match']]

# %%
#For new xg and xga data

#games['avg_home_xg_for_home_team'] = ""
# games['avg_away_xg_against_home_team'] = ""
# games['avg_xg_for_home_team'] = ""
# games['avg_xg_against_home_team'] = ""
# games['avg_home_xg_for_away_team'] = ""
# games['avg_away_xg_against_away_team'] = ""
# games['avg_xg_for_away_team'] = ""
# games['avg_xg_against_away_team'] = ""

# %%
usl_matches = pd.read_csv('../../footy_data/usa-usl-championship-matches-2021-to-2021-stats.csv')

# %%
xg_view = usl_matches[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view[(len(usl_matches) - 50):len(usl_matches)]
# Out:
#              home_team_name          away_team_name  team_a_xg  team_b_xg  \
# 458       New Mexico United             San Antonio       1.79       1.39
# 459        Orange County SC         San Diego Loyal       1.13       1.88
# 460         Tacoma Defiance           Oakland Roots       1.17       1.48
# 461       Hartford Athletic  Charlotte Independence       1.01       1.36
# 462           Real Monarchs        Colorado Springs       0.56       1.77
# 463  Pittsburgh Riverhounds      Charleston Battery       1.41       1.17
# 464             Indy Eleven        Tulsa Roughnecks       1.41       1.38
# 465          Loudoun United       Tampa Bay Rowdies       0.78       1.82
# 466         Louisville City             Memphis 901       1.44       1.19
# 467       Rio Grande Valley       New Mexico United       1.80       0.81
# 468             San Antonio             Austin Bold       2.20       1.16
# 469        Orange County SC        Las Vegas Lights       1.53       0.75
# 470          Phoenix Rising     Sacramento Republic       1.91       1.22
# 471         Tacoma Defiance            LA Galaxy II       2.25       1.49
# 472       Birmingham Legion          Sporting KC II       3.16       1.79
# 473         San Diego Loyal           Oakland Roots       1.47       1.59
# 474                Miami FC          New York RB II       2.05       1.48
# 475      El Paso Locomotive              OKC Energy       1.90       0.62
# 476       Hartford Athletic      Charleston Battery       1.64       1.02
# 477  Charlotte Independence          Loudoun United       1.88       1.13
# 478                Miami FC  Pittsburgh Riverhounds       0.00       0.00
# 479             Memphis 901        Tulsa Roughnecks       2.27       1.39
# 480           Real Monarchs       Rio Grande Valley       1.23       2.05
# 481          Loudoun United          New York RB II       2.27       2.09
# 482             Memphis 901             Indy Eleven       1.61       1.64
# 483  Pittsburgh Riverhounds       Hartford Athletic       1.37       1.01
# 484      Charleston Battery                Miami FC       1.44       1.85
# 485       New Mexico United           Real Monarchs       1.25       1.19
# 486       Birmingham Legion         Louisville City       1.27       1.85
# 487             Austin Bold  Charlotte Independence       1.16       2.50
# 488        Tulsa Roughnecks              OKC Energy       1.57       0.97
# 489       Rio Grande Valley      El Paso Locomotive       1.66       1.01
# 490             San Antonio        Colorado Springs       0.70       0.68
# 491           Oakland Roots          Sporting KC II       0.90       0.86
# 492        Las Vegas Lights       Tampa Bay Rowdies       1.00       1.79
# 493            LA Galaxy II        Orange County SC       1.88       1.12
# 494          Phoenix Rising         Tacoma Defiance       2.23       1.71
# 495     Sacramento Republic         San Diego Loyal       0.70       0.66
# 496             San Antonio         San Diego Loyal       1.40       1.32
# 497      El Paso Locomotive           Oakland Roots       1.85       1.40
# 498  Charlotte Independence             Memphis 901       1.81       0.47
# 499       Tampa Bay Rowdies        Tulsa Roughnecks       2.69       1.03
# 500         Louisville City                Miami FC       2.06       0.90
# 501        Orange County SC        Colorado Springs       0.87       2.41
# 502          Phoenix Rising       Rio Grande Valley       2.11       1.82
# 503       Birmingham Legion  Pittsburgh Riverhounds       0.00       0.00
# 504       Tampa Bay Rowdies       Birmingham Legion       0.00       0.00
# 505         Louisville City  Charlotte Independence       0.00       0.00
# 506             San Antonio       Rio Grande Valley       0.00       0.00
# 507        Orange County SC           Oakland Roots       0.00       0.00
#
#      home_team_goal_count  away_team_goal_count
# 458                     4                     2
# 459                     1                     0
# 460                     0                     0
# 461                     1                     2
# 462                     1                     1
# 463                     2                     1
# 464                     1                     1
# 465                     0                     1
# 466                     3                     1
# 467                     2                     0
# 468                     0                     0
# 469                     2                     1
# 470                     1                     1
# 471                     3                     2
# 472                     6                     0
# 473                     3                     4
# 474                     2                     0
# 475                     4                     0
# 476                     2                     0
# 477                     1                     0
# 478                     0                     1
# 479                     3                     2
# 480                     1                     3
# 481                     1                     4
# 482                     3                     0
# 483                     0                     0
# 484                     0                     4
# 485                     3                     1
# 486                     0                     1
# 487                     1                     1
# 488                     2                     0
# 489                     4                     1
# 490                     3                     0
# 491                     1                     0
# 492                     1                     2
# 493                     0                     1
# 494                     1                     1
# 495                     1                     1
# 496                     2                     0
# 497                     0                     1
# 498                     3                     1
# 499                     6                     2
# 500                     1                     0
# 501                     1                     0
# 502                     3                     3
# 503                     0                     0
# 504                     0                     0
# 505                     0                     0
# 506                     0                     0
# 507                     0                     0

# %%
xg_view[xg_view['home_team_name'] == 'Louisville City']
# Out:
#       home_team_name          away_team_name  team_a_xg  team_b_xg  \
# 0    Louisville City       Atlanta United II       2.36       0.85
# 17   Louisville City       Birmingham Legion       1.80       1.01
# 45   Louisville City         San Diego Loyal       2.02       1.41
# 57   Louisville City             Indy Eleven       1.93       0.88
# 92   Louisville City             Memphis 901       1.95       0.57
# 102  Louisville City       Birmingham Legion       1.28       1.09
# 133  Louisville City             Indy Eleven       1.74       0.94
# 179  Louisville City              OKC Energy       1.38       1.40
# 186  Louisville City       Atlanta United II       1.84       0.64
# 217  Louisville City              OKC Energy       1.70       1.03
# 239  Louisville City          Sporting KC II       2.47       0.75
# 262  Louisville City        Tulsa Roughnecks       1.79       1.15
# 313  Louisville City        Tulsa Roughnecks       1.41       0.62
# 407  Louisville City       New Mexico United       1.30       1.26
# 420  Louisville City          Sporting KC II       1.38       1.04
# 466  Louisville City             Memphis 901       1.44       1.19
# 500  Louisville City                Miami FC       2.06       0.90
# 505  Louisville City  Charlotte Independence       0.00       0.00
#
#      home_team_goal_count  away_team_goal_count
# 0                       2                     0
# 17                      1                     1
# 45                      2                     1
# 57                      1                     2
# 92                      3                     0
# 102                     2                     0
# 133                     3                     3
# 179                     3                     1
# 186                     2                     0
# 217                     2                     1
# 239                     4                     1
# 262                     2                     1
# 313                     0                     1
# 407                     3                     1
# 420                     4                     3
# 466                     3                     1
# 500                     1                     0
# 505                     0                     0

# %%
xg_view[xg_view['away_team_name'] == 'Louisville City']
# Out:
#         home_team_name   away_team_name  team_a_xg  team_b_xg  \
# 83   Atlanta United II  Louisville City       0.85       1.76
# 114   Tulsa Roughnecks  Louisville City       1.69       1.57
# 147     Sporting KC II  Louisville City       1.33       1.49
# 168   Tulsa Roughnecks  Louisville City       1.16       1.40
# 197   Colorado Springs  Louisville City       1.20       1.46
# 211     Sporting KC II  Louisville City       0.69       1.81
# 285         OKC Energy  Louisville City       0.79       1.18
# 295  Birmingham Legion  Louisville City       0.90       1.14
# 328  Hartford Athletic  Louisville City       1.50       2.21
# 347         OKC Energy  Louisville City       0.72       1.27
# 354        Indy Eleven  Louisville City       1.04       1.07
# 378        Memphis 901  Louisville City       0.00       0.00
# 389  Atlanta United II  Louisville City       1.29       1.78
# 432        Memphis 901  Louisville City       1.18       1.23
# 443        Indy Eleven  Louisville City       1.47       1.56
# 486  Birmingham Legion  Louisville City       1.27       1.85
#
#      home_team_goal_count  away_team_goal_count
# 83                      1                     0
# 114                     2                     3
# 147                     2                     4
# 168                     3                     2
# 197                     1                     1
# 211                     1                     2
# 285                     0                     0
# 295                     2                     1
# 328                     2                     4
# 347                     1                     1
# 354                     0                     2
# 378                     1                     1
# 389                     1                     1
# 432                     2                     1
# 443                     1                     0
# 486                     0                     1
